# %% [markdown]
# ROTATE AND OBSERVATION POINTS RETURN

# %%
import numpy as np
import pygame
import math

# Constants
SCREEN_WIDTH = 600
SCREEN_HEIGHT = 600

PREDATOR_RADIUS = 20
FOV_RADIUS = 100

WHITE = (255, 255, 255)
RED = (255, 0, 0)
BLUE = (0, 0, 255)
GREEN = (0, 255, 0)
YELLOW = (255, 255, 0)
ORANGE = (255, 165, 0)
PURPLE = (128, 0, 128)

pygame.init()
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
pygame.display.set_caption('Env render test')

class Agent:
    def __init__(self, agent_name, agent_index):
        self.index = agent_index
        self.agent = agent_name
        self.movement_speed = 1.00
        self.current_position = None
        self.previous_position = np.array([0, 0], dtype=np.float32)
        self.angle = 0
        self.center = 0
        self.direction = 0
        self.direction_end = 0
        self.draw_direction_end = 0
        self.rotation_angle = 20  # Rotation angle when encountering a wall
        self.walls = {
            'wall1': {'x': 150, 'y': 100, 'width': 20, 'height': 100, 'color': BLUE, 'id': 1},
            'wall2': {'x': 250, 'y': 200, 'width': 30, 'height': 60, 'color': GREEN, 'id': 2},
            'wall3': {'x': 350, 'y': 150, 'width': 25, 'height': 30, 'color': YELLOW, 'id': 3},
            'wall4': {'x': 100, 'y': 400, 'width': 20, 'height': 60, 'color': ORANGE, 'id': 4},
            'wall5': {'x': 200, 'y': 300, 'width': 40, 'height': 20, 'color': PURPLE, 'id': 5},
            'wall6': {'x': 450, 'y': 150, 'width': 35, 'height': 45, 'color': RED, 'id': 6},
            'wall7': {'x': 300, 'y': 150, 'width': 25, 'height': 30, 'color': YELLOW, 'id': 7},
            'wall8': {'x': 200, 'y': 400, 'width': 20, 'height': 60, 'color': ORANGE, 'id': 8},
            'wall9': {'x': 700, 'y': 300, 'width': 40, 'height': 20, 'color': PURPLE, 'id': 9},
            'wall10': {'x': 1050, 'y': 150, 'width': 35, 'height': 45, 'color': RED, 'id': 10},
            'wall11': {'x': 450, 'y': 100, 'width': 20, 'height': 100, 'color': BLUE, 'id': 11},
            'wall12': {'x': 950, 'y': 200, 'width': 30, 'height': 60, 'color': GREEN, 'id': 12},
            'wall13': {'x': 150, 'y': 150, 'width': 25, 'height': 30, 'color': YELLOW, 'id': 13},
            'wall14': {'x': 900, 'y': 400, 'width': 20, 'height': 60, 'color': ORANGE, 'id': 14},
            'wall15': {'x': 600, 'y': 300, 'width': 40, 'height': 20, 'color': PURPLE, 'id': 15}
        }

    def agent_reset(self, width, height):
        padding = 30
        self.current_position = np.array(
            [np.random.uniform(30, width - padding), np.random.uniform(30, height - padding)], dtype=np.float32)

        theta = math.radians(self.angle)
        dir_vec_x = padding * math.cos(theta)
        dir_vec_y = padding * math.sin(theta)
        self.direction_end = np.array([self.current_position[0] + dir_vec_x, self.current_position[1] + dir_vec_y],
                                      dtype=np.float32)
        self.draw_direction_end = (self.current_position[0] + dir_vec_x, self.current_position[1] + dir_vec_y)

    def get_direction(self, angle):
        center = (int(self.current_position[0]), int(self.current_position[1]))
        self.center = center

        theta = math.radians(self.angle)
        directional_vector_x = 30 * math.cos(theta)
        directional_vector_y = 30 * math.sin(theta)

        directional_line_end = np.array([center[0] + directional_vector_x, center[1] + directional_vector_y],
                                        dtype=np.float32)
        self.direction_end = directional_line_end

        direction = directional_line_end - center
        direction /= np.linalg.norm(direction)
        self.direction = direction
        self.draw_direction_end = (center[0] + directional_vector_x, center[1] + directional_vector_y)

    def draw_environment(self):
        for wall_data in self.walls.values():
            pygame.draw.rect(screen, wall_data['color'], (wall_data['x'], wall_data['y'], wall_data['width'], wall_data['height']))
            # Draw text label
            font = pygame.font.Font(None, 20)
            label = font.render(f"{wall_data['id']}", True, (255, 255, 255))
            screen.blit(label, (wall_data['x'] + wall_data['width'] // 2 - 10, wall_data['y'] + wall_data['height'] // 2 - 10))

        pygame.draw.circle(screen, BLUE, (int(self.current_position[0]), int(self.current_position[1])), PREDATOR_RADIUS)
        pygame.draw.line(screen, BLUE, (int(self.current_position[0]), int(self.current_position[1])),
                        self.draw_direction_end, 5)
        pygame.draw.circle(screen, BLUE, (int(self.current_position[0]), int(self.current_position[1])), FOV_RADIUS, 1)


    def get_fov_points(self):
        fov_points = {}  

        for x in range(int(self.current_position[0] - FOV_RADIUS), int(self.current_position[0] + FOV_RADIUS)):
            for y in range(int(self.current_position[1] - FOV_RADIUS), int(self.current_position[1] + FOV_RADIUS)):
                if x >= 0 and x < SCREEN_WIDTH and y >= 0 and y < SCREEN_HEIGHT:
                    fov_points[(x, y)] = 0

        for wall_name, wall_data in self.walls.items():
            for x in range(wall_data['x'], wall_data['x'] + wall_data['width']):
                for y in range(wall_data['y'], wall_data['y'] + wall_data['height']):
                    fov_points[(x, y)] = wall_data['color']

        return fov_points

    def step_update(self, action, range_x, range_y, walls):
        self.previous_position = np.copy(self.current_position)

        if action == 0:
            self.angle += 10
            self.get_direction(self.angle)

        elif action == 1:
            self.angle -= 10
            self.get_direction(self.angle)

        elif action == 2:
            new_position = self.current_position + self.direction * self.movement_speed

            if not self.check_wall_collision(new_position, walls):
                self.current_position = new_position
            else:
                self.rotate_towards_open_direction()

            self.get_direction(self.angle)

        elif action == 3:
            new_position = self.current_position - self.direction * self.movement_speed

            if not self.check_wall_collision(new_position, walls):
                self.current_position = new_position
            else:
                self.rotate_towards_open_direction()

            self.get_direction(self.angle)

        elif action == 4:
            pass

        self.current_position[0] = np.clip(self.current_position[0], 0, range_x)
        self.current_position[1] = np.clip(self.current_position[1], 0, range_y)

    

    def check_wall_collision(self, new_position, walls):
        for wall_data in walls.values():
            if (
                new_position[0] + 15 > wall_data['x']
                and new_position[0] - 15 < wall_data['x'] + wall_data['width']
                and new_position[1] + 15 > wall_data['y']
                and new_position[1] - 15 < wall_data['y'] + wall_data['height']
            ):
                return True  # Collision detected

        return False  # No collision

    def rotate_towards_open_direction(self):
        # Rotate either clockwise or anticlockwise based on a random choice
        rotation_direction = np.random.choice([-1, 1])
        self.angle += rotation_direction * self.rotation_angle
        self.get_direction(self.angle)

    def detect_overlapping_walls(self):
        overlapping_walls = []

        for wall_name, wall_data in self.walls.items():
            for x in range(wall_data['x'], wall_data['x'] + wall_data['width']):
                for y in range(wall_data['y'], wall_data['y'] + wall_data['height']):
                    distance_to_wall = np.linalg.norm(np.array([x, y]) - self.current_position)

                    if distance_to_wall <= FOV_RADIUS:
                        overlapping_walls.append({
                            'name': wall_name,
                            'id': wall_data['id'],
                            'color': wall_data['color'],
                            'x': x,
                            'y': y
                        })

        return overlapping_walls


# Create agent and initialize environment
agent = Agent('predator', 1)
agent.agent_reset(SCREEN_WIDTH, SCREEN_HEIGHT)

running = True

while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    screen.fill(WHITE)
    agent.step_update(2, SCREEN_WIDTH, SCREEN_HEIGHT, agent.walls)
    agent.draw_environment()

    overlapping_walls = agent.detect_overlapping_walls()

    # Print details of overlapping walls
    for wall in overlapping_walls:
        print(f"Overlapping Wall - Name: {wall['name']}, ID: {wall['id']}, Coordinates: ({wall['x']}, {wall['y']})")

    pygame.display.update()
    pygame.time.delay(5)

pygame.quit()
# Out:
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (150, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (151, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (152, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (153, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (154, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (155, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 160)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 161)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 162)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 163)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 164)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 165)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 166)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 167)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 168)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 169)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 170)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 171)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 172)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 173)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 174)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 175)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 176)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 177)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 178)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 179)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 180)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 181)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 182)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 183)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 184)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 185)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 186)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 187)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 188)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 189)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 190)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 191)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 192)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 193)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 194)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 195)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 196)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 197)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 198)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (156, 199)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 100)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 101)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 102)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 103)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 104)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 105)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 106)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 107)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 108)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 109)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 110)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 111)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 112)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 113)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 114)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 115)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 116)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 117)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 118)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 119)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 120)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 121)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 122)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 123)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 124)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 125)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 126)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 127)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 128)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 129)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 130)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 131)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 132)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 133)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 134)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 135)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 136)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 137)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 138)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 139)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 140)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 141)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 142)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 143)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 144)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 145)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 146)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 147)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 148)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 149)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 150)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 151)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 152)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 153)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 154)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 155)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 156)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 157)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 158)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 159)
# Overlapping Wall - Name: wall1, ID: 1, Coordinates: (157, 160)
# ...
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (166, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (166, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (166, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (166, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (166, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (166, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (167, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (168, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (169, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (170, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (171, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (172, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (173, 179)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 150)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 151)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 152)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 153)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 154)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 155)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 156)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 157)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 158)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 159)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 160)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 161)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 162)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 163)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 164)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 165)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 166)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 167)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 168)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 169)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 170)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 171)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 172)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 173)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 174)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 175)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 176)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 177)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 178)
# Overlapping Wall - Name: wall13, ID: 13, Coordinates: (174, 179)

# %% [markdown]
# WALLS AND STOP

# %%
import pygame
import numpy as np
import math
import random

class GameEnv:
    def __init__(self):
        # Constants
        self.SCREEN_WIDTH = 600
        self.SCREEN_HEIGHT = 600
        self.PREDATOR_RADIUS = 20
        self.FOV_RADIUS = 100
        self.WHITE = (255, 255, 255)
        self.BLUE = (0, 0, 255)

        pygame.init()
        self.screen = pygame.display.set_mode((self.SCREEN_WIDTH, self.SCREEN_HEIGHT))
        pygame.display.set_caption('Simple Env')

        # Random initial position for the predator
        self.predator_position = np.array([random.uniform(30, self.SCREEN_WIDTH - 30), random.uniform(30, self.SCREEN_HEIGHT - 30)],
                                          dtype=np.float32)

        self.predator_angle = 0
        self.predator_speed = 1.0

        self.walls = {
            'wall1': {'x': 150, 'y': 100, 'width': 20, 'height': 100, 'color': BLUE, 'id': 1},
            'wall2': {'x': 250, 'y': 200, 'width': 30, 'height': 60, 'color': GREEN, 'id': 2},
            'wall3': {'x': 350, 'y': 150, 'width': 25, 'height': 30, 'color': YELLOW, 'id': 3},
            'wall4': {'x': 100, 'y': 400, 'width': 20, 'height': 60, 'color': ORANGE, 'id': 4},
            'wall5': {'x': 200, 'y': 300, 'width': 40, 'height': 20, 'color': PURPLE, 'id': 5},
            'wall6': {'x': 450, 'y': 150, 'width': 35, 'height': 45, 'color': RED, 'id': 6},
            'wall7': {'x': 300, 'y': 150, 'width': 25, 'height': 30, 'color': YELLOW, 'id': 7},
            'wall8': {'x': 200, 'y': 400, 'width': 20, 'height': 60, 'color': ORANGE, 'id': 8},
            'wall9': {'x': 700, 'y': 300, 'width': 40, 'height': 20, 'color': PURPLE, 'id': 9},
            'wall10': {'x': 1050, 'y': 150, 'width': 35, 'height': 45, 'color': RED, 'id': 10}
        }

    def draw_environment(self):
        for wall_data in self.walls.values():
            pygame.draw.rect(self.screen, wall_data['color'],
                             (wall_data['x'], wall_data['y'], wall_data['width'], wall_data['height']))

        pygame.draw.circle(self.screen, self.BLUE, (int(self.predator_position[0]), int(self.predator_position[1])),
                           self.PREDATOR_RADIUS)
        pygame.draw.circle(self.screen, self.BLUE, (int(self.predator_position[0]), int(self.predator_position[1])),
                           self.FOV_RADIUS, 1)

    def check_wall_collision(self, new_position):
        for wall_data in self.walls.values():
            if (
                new_position[0] + self.PREDATOR_RADIUS > wall_data['x']
                and new_position[0] - self.PREDATOR_RADIUS < wall_data['x'] + wall_data['width']
                and new_position[1] + self.PREDATOR_RADIUS > wall_data['y']
                and new_position[1] - self.PREDATOR_RADIUS < wall_data['y'] + wall_data['height']
            ):
                return True  # Collision detected
        return False  # No collision

    def update_predator_position(self):
        new_position = self.predator_position + self.predator_speed * np.array(
            [math.cos(math.radians(self.predator_angle)), math.sin(math.radians(self.predator_angle))])

        if not self.check_wall_collision(new_position):
            self.predator_position = new_position

    def run_game(self):
        running = True

        while running:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False

            self.screen.fill(self.WHITE)

            self.update_predator_position()
            self.draw_environment()

            pygame.display.update()
            pygame.time.delay(20)

        pygame.quit()


if __name__ == "__main__":
    game_env = GameEnv()
    game_env.run_game()

# %%
pygame.quit()

# %% [markdown]
# Slanted walls and stop

# %%
import pygame
import numpy as np
import math
import random

class GameEnv:
    def __init__(self):
        # Constants
        self.SCREEN_WIDTH = 600
        self.SCREEN_HEIGHT = 600
        self.PREDATOR_RADIUS = 20
        self.FOV_RADIUS = 100
        self.WHITE = (255, 255, 255)
        self.BLUE = (0, 0, 255)
        self.GREEN = (0, 255, 0)  # Green color for the wall

        pygame.init()
        self.screen = pygame.display.set_mode((self.SCREEN_WIDTH, self.SCREEN_HEIGHT))
        pygame.display.set_caption('Simple Env')

        # Random initial position for the predator
        self.predator_position = np.array([random.uniform(30, self.SCREEN_WIDTH - 30), random.uniform(30, self.SCREEN_HEIGHT - 30)],
                                          dtype=np.float32)

        self.predator_angle = 0
        self.predator_speed = 1.0

        # Slanted wall (diagonally slanted)
        self.slanted_wall_start = (200, 100)
        self.slanted_wall_end = (300, 200)
        self.calculate_slanted_wall()

    def calculate_slanted_wall(self):
        dx = self.slanted_wall_end[0] - self.slanted_wall_start[0]
        dy = self.slanted_wall_end[1] - self.slanted_wall_start[1]
        self.slanted_wall_length = int(np.sqrt(dx**2 + dy**2))

        angle = np.arctan2(dy, dx)
        self.slanted_wall_angle = math.degrees(angle)

        self.slanted_wall_points = np.linspace(self.slanted_wall_start, self.slanted_wall_end, self.slanted_wall_length)

    def draw_environment(self):
        pygame.draw.line(self.screen, self.GREEN, self.slanted_wall_start, self.slanted_wall_end, 45)  # Green wall

        pygame.draw.circle(self.screen, self.BLUE, (int(self.predator_position[0]), int(self.predator_position[1])),
                           self.PREDATOR_RADIUS)
        pygame.draw.circle(self.screen, self.BLUE, (int(self.predator_position[0]), int(self.predator_position[1])),
                           self.FOV_RADIUS, 1)

    def check_wall_collision(self, new_position):
        # Check collision with the slanted wall
        for point in self.slanted_wall_points:
            if (
                new_position[0] + self.PREDATOR_RADIUS > point[0]
                and new_position[0] - self.PREDATOR_RADIUS < point[0]
                and new_position[1] + self.PREDATOR_RADIUS > point[1]
                and new_position[1] - self.PREDATOR_RADIUS < point[1]
            ):
                return True  # Collision detected

        return False  # No collision

    # calculates the new position of the predator based on its current position, 
    # angle of movement (predator_angle), and speed (predator_speed). It uses 
    # trigonometric functions (cos and sin) to determine the change in x and y coordinates 
    # based on the movement angle.
    
    def update_predator_position(self):
        new_position = self.predator_position + self.predator_speed * np.array(
            [math.cos(math.radians(self.predator_angle)), math.sin(math.radians(self.predator_angle))])

        # Checks if the new position would result in a collision with the wall.
        # If there is no collision, the predator is allowed to move.
        if not self.check_wall_collision(new_position):  
            self.predator_position = new_position

    def run_game(self):
        running = True

        while running:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False

            self.screen.fill(self.WHITE)

            self.update_predator_position()
            self.draw_environment()

            pygame.display.update()
            pygame.time.delay(5)

        pygame.quit()


if __name__ == "__main__":
    game_env = GameEnv()
    game_env.run_game()
