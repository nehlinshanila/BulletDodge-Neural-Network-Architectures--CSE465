# %%
import numpy as np

# %%
class Agent:
    def __init__(self, agent_name, agent_index):
        self.index = agent_index
        self.agent = agent_name
        self.health = None
        self.isHit = False
        self.move = True
        self.movement_speed = 1.00
        self.previous_position = np.array([0, 0], dtype=np.float32)
        self.current_position = None
        self.same_position = False
        self.current_step = 0
        self.action = None
        pass

    def agent_action(self, action):

        pass

    def agent_reset(self, width, height):
        padding = 30
        self.current_position = np.array(
            [np.random.uniform(30, width - padding), np.random.uniform(30, width - padding)], dtype=np.float32)

    def step_update(self, action, range_x, range_y):

        if action == 0:
            self.current_position[0] -= self.movement_speed
        elif action == 1:
            self.current_position[0] += self.movement_speed
        elif action == 2:
            self.current_position[1] -= self.movement_speed
        elif action == 3:
            self.current_position[1] += self.movement_speed
        
        self.current_position[0] = np.clip(self.current_position[0], 0, range_x)
        self.current_position[1] = np.clip(self.current_position[1], 0, range_y)

# %%
from gymnasium.spaces import Discrete, Box, MultiDiscrete
from gymnasium import Env
import numpy as np
import pygame
import time

# %%
class GameEnv(Env):
    def __init__(self, screen_width=400, screen_height=400, render_mode='human'):
        super(GameEnv, self).__init__()

        # defining the screen dimension for render purpose
        self.screen_width = screen_width
        self.screen_height = screen_height
        self.render_mode = render_mode

        # defining the observation and action spaces for all the agents
        
        self.observation_space = Box(low=np.array([0, 0, 0, 0], dtype=np.float32),
                                    high=np.array([self.screen_width, self.screen_height, self.screen_width, self.screen_height], dtype=np.float32),
                                    dtype=np.float32)

        # the pygame window should be initialized in the render function

        # setting the total number of agent
        
        self.number_of_prey = 1
        self.number_of_predator = 1
        self.prey_agent = None
        self.predator_agent = None
        self.predator_i_position = None
        self.initial_distance = None
        self.current_distance = None
        self.previous_distance = None
        self.predator_total_reward = 0
        self.number_of_agents = self.number_of_prey + self.number_of_prey

        # defining the action space based on total number of predator and prey
        self.action_space = Discrete(4)


        # setting the total number of obstacles
        self.total_obstacles = None

        # keeping a counter to save the total steps
        self.total_steps = 0

        # initializing the pygame
        pygame.init()

        # setting the screen size
        self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
        pygame.display.set_caption('Multi Agent Environment(simple)')
        
        # keep the track of time of the rendering
        self.clock = pygame.time.Clock()

        # *it is set in milisec format (time is sec is time/1000)
        self.total_running_time = 10

        # start the tick timer
        self.start_time = 0
        # print(f'start  time: {self.start_time}')

        # initializing the font
        pygame.font.init()
        self.font = pygame.font.Font(None, 18)

    # this function rerturns the value of the action into 2 digits 
    # if the action_space.sample() gives 1 digit number
    # * if  the number is 3 it will return 03 
    # * if  the number is 14 then it will return 14
    def expand_action_digit(self, action):

        # this basically checks the number if it has 1 then fills the rest with 0
        # if the number is 2 digits then it stays the same
        action = str(action).zfill(2)
        prey_action = int(action[0]) % 4
        predator_action = int(action[1]) % 4
        return prey_action, predator_action
        

    # this method will initialize the number of agents
    # ! this must be called from outside
    def agent_init(self):

        prey_agents = Agent('prey', 0)

        predator_agents = Agent('predator', 0)

        self.prey_agent = prey_agents
        self.predator_agent = predator_agents
        

    # this function is used to explicitly set the number of agents
    # ! this needs to be called from outside
    def set_agent_number(self, prey_number, predator_number):
        self.number_of_predator = predator_number
        self.number_of_prey = prey_number

    # the usual reset function
    def reset(self, seed=0):
        self.start_time = time.time()
        
        self.agent_init()

        self.total_steps = 0
        self.predator_total_reward = 0

        prey = self.prey_agent
        predator = self.predator_agent

        # for prey in self.prey_agents:
        prey.agent_reset(width=self.screen_width, height=self.screen_height)
        # observation.append([prey.index, prey.agent, prey.current_position])

        # for predator in self.predator_agents:
        predator.agent_reset(width=self.screen_width, height=self.screen_height)
        # observation.append([predator.index, predator.agent, predator.current_position])
        
        # setting the predator and prey to their initial position
        self.prey_agent = prey
        self.predator_agent = predator

        # setting the initial position of predator for reward
        self.predator_i_position = self.predator_agent.current_position
        
        # calculating the initial distance of 2 agents
        direction = self.predator_agent.current_position - self.prey_agent.current_position
        self.initial_distance = np.linalg.norm(direction)

        # observation :
        # all the variable values inside the obsercation space needs to be sent inside the observation variable
        observation = np.concatenate([self.prey_agent.current_position, self.predator_agent.current_position])
        # observation = self.initial_distance
        return observation, seed

    # the step function
    # this function is called for every timesteps
    # this function updates the actions or states of agents in the env
    # this function is called default by the algorithms of all sorts
    # * it returns observation, reward, done, truncated, info
    # * any game policy change can be done here
    # * reward must be set here
    def step(self, action):
        
        # initializing the return variables
        done = False
        reward = 0
        truncated = False
        info = {}
        current_time = time.time()
        # print(f'current time: {current_time}')
        # when ever the step is starting set the start time
        # if self.total_steps == 0:
        #     self.start_time = pygame.time.get_ticks()
        # else:
        #     current_time = pygame.time.get_ticks()

        elapsed_time = current_time - self.start_time
        # print(f'elapsed time: {elapsed_time}')
        # handles the pygame window event when closing
        # !if the window still crashes pygame.event needs to be managed properly
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                done = True
                pygame.quit()
        
        # print(f'action: {action}')
        # *the actions are split as required
        # prey_action, predator_action = self.expand_action_digit(action)
        predator_action = action
        predator = self.predator_agent
        # print(f'prey: {prey_action}, predator: {predator_action}')
                

        # print(f'predator_{predator.index} = action:{action} current_position: {predator.current_position}')
        predator.step_update(action=predator_action, range_x=self.screen_width - 10, range_y=self.screen_height - 10)
        # print(f'predator_{predator.index}: new_position: {predator.current_position}')
            
        # !observation.append({'index': predator.index, 'name': predator.agent, 'position': predator.current_position})
        # observation = self.predator_agent.current_position
        observation = np.concatenate([self.prey_agent.current_position, self.predator_agent.current_position])

        # print(f'observation: {self.predator_agent.current_position}')
        self.total_steps += 1

        direction = self.predator_agent.current_position - self.prey_agent.current_position

        # Calculate the distance between the centers of the two dots
        distance_between_centers = np.linalg.norm(direction)
        # observation =  distance_between_centers

        self.current_distance = distance_between_centers

        if self.current_distance < self.initial_distance:
            self.initial_distance = self.current_distance
            reward += 0.01
        else:
            reward -= 0.09

        # check everystep if the distance of two agents are:
        # greater than  initial distance?  
        # yes: -reward
        # no: +reward

        # if distance_between_centers > self.initial_distance:
        #     reward -= 0.06
        # else:
        #     reward += 0.01
            
        # Check if there is a collision (distance <= sum of radii)
        if elapsed_time <= self.total_running_time:
            if distance_between_centers <= 20:
                reward += 100
                done = True
                    # pygame.quit()
                    # self.close()
            # if self.total_steps == 30000:
            #     done = True
        else:
            done = True
            reward -= 50
                # pygame.quit()
                # self.close()

        # print(self.total_steps)
        self.render()
        # it will update the total reward everystep
        self.predator_total_reward = reward

        return observation, reward, done, truncated, info
        

    def render(self):
        if self.render_mode == 'human':
            screen = self.screen

            # clear screen
            screen.fill((255, 255, 255))
            prey = self.prey_agent
            pos_x, pos_y = prey.current_position
            prey_radius = 10
            pygame.draw.circle(screen, (0, 0, 255), (int(pos_x), int(pos_y)), prey_radius)

            predator = self.predator_agent
            pos_x, pos_y = predator.current_position
            predator_radius = 10

            pygame.draw.circle(screen, (255, 0, 0), (int(pos_x), int(pos_y)), predator_radius)

            text_surface = self.font.render(f"Reward: {self.predator_total_reward: .5f} initial distance: {self.initial_distance: .2f} current_distance:{self.current_distance: .2f}", True, (0, 0, 0))

            text_rect = text_surface.get_rect()

            text_rect.center = (self.screen_width - 200, 10)

            self.screen.blit(text_surface, text_rect)

            pygame.display.update()

    def close(self):
        pygame.quit()

# %%
env.close()

# %% [markdown]
# Testing the environment

# %%
env = GameEnv()
for i in range(0, 5):
    done = False

    # env.agent_init()
    env.reset()
    total_reward = 0
    while not done:
        action = env.action_space.sample()
        obs, reward, done, _, _ = env.step(action)
        # total_reward += reward
    print(f'total reward: {reward}')
    print(f'Number of steps: {env.total_steps}')
        # env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\jupyter\Reinforcement Learning\Test\proxi_reward.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> while not done:
#       <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>     action = env.action_space.sample()
# ---> <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     obs, reward, done, _, _ = env.step(action)
#      <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>     # total_reward += reward
#      <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> print(f'total reward: {reward}')
#
# c:\jupyter\Reinforcement Learning\Test\proxi_reward.ipynb Cell 7 line 2
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=212'>213</a>     reward -= 80
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=213'>214</a>         # pygame.quit()
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=214'>215</a>         # self.close()
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=215'>216</a>
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=216'>217</a> # print(self.total_steps)
# --> <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=217'>218</a> self.render()
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=218'>219</a> # it will update the total reward everystep
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=219'>220</a> self.predator_total_reward = reward
#
# c:\jupyter\Reinforcement Learning\Test\proxi_reward.ipynb Cell 7 line 2
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=245'>246</a> text_rect.center = (self.screen_width - 200, 10)
#     <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=247'>248</a> self.screen.blit(text_surface, text_rect)
# --> <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#W6sZmlsZQ%3D%3D?line=249'>250</a> pygame.display.update()
#
# KeyboardInterrupt:

# %%
from stable_baselines3 import PPO, DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
log_path = os.path.join('Training', 'Logs', 'Proximal_reward')
baseline_path = os.path.join('Training', 'Models', 'proxi_baseline')

# %%
env = GameEnv()

env.reset()
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=100000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\Proximal_reward\PPO_10
# -----------------------------
# | time/              |      |
# |    fps             | 328  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | -296        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013213438 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00121    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0111     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 0.047       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.49e+03    |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 260         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008612952 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 1.06e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 24.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48e+03    |
# |    ep_rew_mean          | -299        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012357251 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 9.26e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 23.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | -303        |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005907228 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -9.06e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000891   |
# |    value_loss           | 23.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 6           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010833016 |
# |    clip_fraction        | 0.0947      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000424    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00111    |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -294        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010763713 |
# |    clip_fraction        | 0.00874     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.49        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000942   |
# |    value_loss           | 22.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.39e+03     |
# |    ep_rew_mean          | -290         |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 8            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0062252376 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.0118      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.02         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -295        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 9           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006600799 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -1.28e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0246     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 2.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45e+03    |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 10          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010654833 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.000272    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 21.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21e+03    |
# |    ep_rew_mean          | -263        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 11          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012946303 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 21.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21e+03    |
# |    ep_rew_mean          | -263        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 12          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009511684 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.00119    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.186       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 31.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23e+03    |
# |    ep_rew_mean          | -266        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 13          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010114162 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00921     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 0.00043     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11e+03    |
# |    ep_rew_mean          | -247        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 14          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010205866 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00116    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 2.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.15e+03     |
# |    ep_rew_mean          | -252         |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 15           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0024116584 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.0495       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.5         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -6.12e-05    |
# |    value_loss           | 30.8         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.15e+03      |
# |    ep_rew_mean          | -252          |
# | time/                   |               |
# |    fps                  | 244           |
# |    iterations           | 16            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00012363575 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | 0.109         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14.4          |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000435     |
# |    value_loss           | 20.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -255         |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 17           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0014281861 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0231       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000538    |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.22e+03     |
# |    ep_rew_mean          | -260         |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 18           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0057329186 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0122       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e-05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 2.46         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.2e+03      |
# |    ep_rew_mean          | -259         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 19           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 7.237727e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.000789     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.6         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -9.26e-05    |
# |    value_loss           | 21           |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.2e+03       |
# |    ep_rew_mean          | -259          |
# | time/                   |               |
# |    fps                  | 239           |
# |    iterations           | 20            |
# |    time_elapsed         | 170           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00022135276 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | 0.0761        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.56          |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -9.57e-05     |
# |    value_loss           | 20.3          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.21e+03     |
# |    ep_rew_mean          | -261         |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 21           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0035092728 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.0302      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -5.97e-05    |
# |    value_loss           | 20.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23e+03    |
# |    ep_rew_mean          | -264        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 22          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004430539 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.0114      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.23e+03     |
# |    ep_rew_mean          | -264         |
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 23           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0025822092 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.00465      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.8         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000418    |
# |    value_loss           | 20.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+03    |
# |    ep_rew_mean          | -266        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 24          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009038843 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00613     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 0.00873     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26e+03    |
# |    ep_rew_mean          | -268        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 25          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014710342 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.00112     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 2.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.29e+03     |
# |    ep_rew_mean          | -271         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 26           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0046543116 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00133     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14           |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000946    |
# |    value_loss           | 20.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.3e+03      |
# |    ep_rew_mean          | -272         |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 27           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0009835815 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.00215     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.497        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 20.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3e+03     |
# |    ep_rew_mean          | -272        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 28          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004798132 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 20.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.29e+03    |
# |    ep_rew_mean          | -272        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 29          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008825917 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 7.7e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0151      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000431   |
# |    value_loss           | 0.00289     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.3e+03     |
# |    ep_rew_mean          | -273        |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 30          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007458399 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00512     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0181      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000164   |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.32e+03      |
# |    ep_rew_mean          | -275          |
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 31            |
# |    time_elapsed         | 262           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00010398732 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.00985       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 25.6          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | 0.000146      |
# |    value_loss           | 20.1          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.32e+03      |
# |    ep_rew_mean          | -275          |
# | time/                   |               |
# |    fps                  | 241           |
# |    iterations           | 32            |
# |    time_elapsed         | 270           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00018813292 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 0.00773       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.71          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 1.82e-05      |
# |    value_loss           | 20.3          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.32e+03    |
# |    ep_rew_mean          | -276        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 33          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008880703 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.000199   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000802   |
# |    value_loss           | 20          |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\jupyter\Reinforcement Learning\Test\proxi_reward.ipynb Cell 10 line 5
#       <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> env.reset()
#       <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# ----> <a href='vscode-notebook-cell:/c%3A/jupyter/Reinforcement%20Learning/Test/proxi_reward.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> model.learn(total_timesteps=100000)
#
# File c:\Users\jahin\anaconda3\envs\myenv\Lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File c:\Users\jahin\anaconda3\envs\myenv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:281, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     278         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     279         self.logger.dump(step=self.num_timesteps)
# --> 281     self.train()
#     283 callback.on_training_end()
#     285 return self
#
# File c:\Users\jahin\anaconda3\envs\myenv\Lib\site-packages\stable_baselines3\ppo\ppo.py:228, in PPO.train(self)
#     226 # Logging
#     227 pg_losses.append(policy_loss.item())
# --> 228 clip_fraction = th.mean((th.abs(ratio - 1) > clip_range).float()).item()
#     229 clip_fractions.append(clip_fraction)
#     231 if self.clip_range_vf is None:
#     232     # No clipping
#
# KeyboardInterrupt:

# %%
model.save(baseline_path)

# %%
env.close()

# %%
del model

# %%
dqn_log_path = os.path.join('Training', 'Logs', 'DQN')
dqn_model_path = os.path.join('Training', 'Models', 'DQN_baseline_2')

# %%
env = GameEnv()
# env.reset()
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=dqn_log_path)
model.learn(total_timesteps=2000000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\DQN\DQN_12
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.52e+04  |
# |    ep_rew_mean      | -1.41e+03 |
# |    exploration_rate | 0.711     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 1519      |
# |    time_elapsed     | 40        |
# |    total_timesteps  | 60791     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 0.0131    |
# |    n_updates        | 2697      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05e+04 |
# |    ep_rew_mean      | -987     |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1050     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 84029    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 8507     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.79e+03 |
# |    ep_rew_mean      | -835     |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 879      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 105530   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0092   |
# |    n_updates        | 13882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.93e+03 |
# |    ep_rew_mean      | -756     |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 792      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 126801   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 19200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.34e+03 |
# |    ep_rew_mean      | -705     |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 734      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 146864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00407  |
# |    n_updates        | 24215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.95e+03 |
# |    ep_rew_mean      | -670     |
# |    exploration_rate | 0.207    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 695      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 166865   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00906  |
# |    n_updates        | 29216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.59e+03 |
# |    ep_rew_mean      | -630     |
# |    exploration_rate | 0.124    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 665      |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 184413   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 33603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.36e+03 |
# |    ep_rew_mean      | -611     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 641      |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 203405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00593  |
# |    n_updates        | 38351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.16e+03 |
# |    ep_rew_mean      | -594     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 620      |
# |    time_elapsed     | 357      |
# |    total_timesteps  | 221777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00967  |
# |    n_updates        | 42944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.88e+03 |
# |    ep_rew_mean      | -565     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 607      |
# |    time_elapsed     | 387      |
# |    total_timesteps  | 235342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00805  |
# |    n_updates        | 46335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.81e+03 |
# |    ep_rew_mean      | -559     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 597      |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 255524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00531  |
# |    n_updates        | 51380    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.65e+03 |
# |    ep_rew_mean      | -541     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 591      |
# |    time_elapsed     | 457      |
# |    total_timesteps  | 271064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00215  |
# |    n_updates        | 55265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.61e+03 |
# |    ep_rew_mean      | -539     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 585      |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 291655   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00335  |
# |    n_updates        | 60413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.5e+03  |
# |    ep_rew_mean      | -526     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 581      |
# |    time_elapsed     | 529      |
# |    total_timesteps  | 307753   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.004    |
# |    n_updates        | 64438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.47e+03 |
# |    ep_rew_mean      | -524     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 577      |
# |    time_elapsed     | 569      |
# |    total_timesteps  | 328402   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00484  |
# |    n_updates        | 69600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.39e+03 |
# |    ep_rew_mean      | -516     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 573      |
# |    time_elapsed     | 601      |
# |    total_timesteps  | 345269   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00504  |
# |    n_updates        | 73817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.38e+03 |
# |    ep_rew_mean      | -515     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 569      |
# |    time_elapsed     | 641      |
# |    total_timesteps  | 365521   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00351  |
# |    n_updates        | 78880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.3e+03  |
# |    ep_rew_mean      | -506     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 566      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 381327   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00475  |
# |    n_updates        | 82831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.28e+03 |
# |    ep_rew_mean      | -504     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 562      |
# |    time_elapsed     | 713      |
# |    total_timesteps  | 400928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0052   |
# |    n_updates        | 87731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.26e+03 |
# |    ep_rew_mean      | -503     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 558      |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 420429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00202  |
# |    n_updates        | 92607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.17e+03 |
# |    ep_rew_mean      | -494     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 553      |
# |    time_elapsed     | 783      |
# |    total_timesteps  | 433877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 95969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5e+03    |
# |    ep_rew_mean      | -474     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 552      |
# |    time_elapsed     | 797      |
# |    total_timesteps  | 440399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00173  |
# |    n_updates        | 97599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5e+03    |
# |    ep_rew_mean      | -474     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 549      |
# |    time_elapsed     | 837      |
# |    total_timesteps  | 459886   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0023   |
# |    n_updates        | 102471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.98e+03 |
# |    ep_rew_mean      | -474     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 545      |
# |    time_elapsed     | 877      |
# |    total_timesteps  | 478416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 107103   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.92e+03 |
# |    ep_rew_mean      | -467     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 539      |
# |    time_elapsed     | 912      |
# |    total_timesteps  | 492057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00337  |
# |    n_updates        | 110514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44e+03 |
# |    ep_rew_mean      | -423     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 535      |
# |    time_elapsed     | 942      |
# |    total_timesteps  | 504479   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00221  |
# |    n_updates        | 113619   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.39e+03 |
# |    ep_rew_mean      | -418     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 531      |
# |    time_elapsed     | 982      |
# |    total_timesteps  | 522573   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0031   |
# |    n_updates        | 118143   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.36e+03 |
# |    ep_rew_mean      | -416     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 529      |
# |    time_elapsed     | 1022     |
# |    total_timesteps  | 541653   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00187  |
# |    n_updates        | 122913   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.31e+03 |
# |    ep_rew_mean      | -410     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 527      |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 557766   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00137  |
# |    n_updates        | 126941   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.3e+03  |
# |    ep_rew_mean      | -409     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 525      |
# |    time_elapsed     | 1096     |
# |    total_timesteps  | 576641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000953 |
# |    n_updates        | 131660   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | -407     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 523      |
# |    time_elapsed     | 1137     |
# |    total_timesteps  | 595153   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00317  |
# |    n_updates        | 136288   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | -408     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 519      |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 611949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00208  |
# |    n_updates        | 140487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.24e+03 |
# |    ep_rew_mean      | -403     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 517      |
# |    time_elapsed     | 1213     |
# |    total_timesteps  | 627481   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00235  |
# |    n_updates        | 144370   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.23e+03 |
# |    ep_rew_mean      | -403     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 514      |
# |    time_elapsed     | 1253     |
# |    total_timesteps  | 645205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000549 |
# |    n_updates        | 148801   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | -408     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 512      |
# |    time_elapsed     | 1293     |
# |    total_timesteps  | 663105   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0023   |
# |    n_updates        | 153276   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25e+03 |
# |    ep_rew_mean      | -406     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 510      |
# |    time_elapsed     | 1333     |
# |    total_timesteps  | 680747   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00202  |
# |    n_updates        | 157686   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.28e+03 |
# |    ep_rew_mean      | -409     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 508      |
# |    time_elapsed     | 1373     |
# |    total_timesteps  | 698692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00198  |
# |    n_updates        | 162172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2e+03  |
# |    ep_rew_mean      | -401     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 506      |
# |    time_elapsed     | 1404     |
# |    total_timesteps  | 711905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000696 |
# |    n_updates        | 165476   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.22e+03 |
# |    ep_rew_mean      | -405     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 505      |
# |    time_elapsed     | 1444     |
# |    total_timesteps  | 729715   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00272  |
# |    n_updates        | 169928   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.18e+03 |
# |    ep_rew_mean      | -401     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 502      |
# |    time_elapsed     | 1484     |
# |    total_timesteps  | 746217   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00209  |
# |    n_updates        | 174054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | -393     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 501      |
# |    time_elapsed     | 1506     |
# |    total_timesteps  | 755600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00181  |
# |    n_updates        | 176399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | -385     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 500      |
# |    time_elapsed     | 1536     |
# |    total_timesteps  | 768664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000326 |
# |    n_updates        | 179665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | -386     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 499      |
# |    time_elapsed     | 1572     |
# |    total_timesteps  | 785449   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00105  |
# |    n_updates        | 183862   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | -385     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 498      |
# |    time_elapsed     | 1612     |
# |    total_timesteps  | 804089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00148  |
# |    n_updates        | 188522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | -384     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 497      |
# |    time_elapsed     | 1652     |
# |    total_timesteps  | 822634   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00132  |
# |    n_updates        | 193158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | -384     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 496      |
# |    time_elapsed     | 1682     |
# |    total_timesteps  | 836057   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00162  |
# |    n_updates        | 196514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | -399     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 495      |
# |    time_elapsed     | 1722     |
# |    total_timesteps  | 853825   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000782 |
# |    n_updates        | 200956   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | -398     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 494      |
# |    time_elapsed     | 1762     |
# |    total_timesteps  | 871429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000966 |
# |    n_updates        | 205357   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | -398     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 493      |
# |    time_elapsed     | 1802     |
# |    total_timesteps  | 889960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000619 |
# |    n_updates        | 209989   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.16e+03 |
# |    ep_rew_mean      | -403     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 492      |
# |    time_elapsed     | 1842     |
# |    total_timesteps  | 907619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00091  |
# |    n_updates        | 214404   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.21e+03 |
# |    ep_rew_mean      | -409     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 491      |
# |    time_elapsed     | 1882     |
# |    total_timesteps  | 925140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00038  |
# |    n_updates        | 218784   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.2e+03  |
# |    ep_rew_mean      | -408     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 490      |
# |    time_elapsed     | 1922     |
# |    total_timesteps  | 943021   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000894 |
# |    n_updates        | 223255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.19e+03 |
# |    ep_rew_mean      | -407     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 489      |
# |    time_elapsed     | 1962     |
# |    total_timesteps  | 960732   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000547 |
# |    n_updates        | 227682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.17e+03 |
# |    ep_rew_mean      | -404     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 488      |
# |    time_elapsed     | 1993     |
# |    total_timesteps  | 974347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00261  |
# |    n_updates        | 231086   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | -397     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 488      |
# |    time_elapsed     | 2024     |
# |    total_timesteps  | 988006   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000924 |
# |    n_updates        | 234501   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | -396     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 487      |
# |    time_elapsed     | 2064     |
# |    total_timesteps  | 1005393  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000568 |
# |    n_updates        | 238848   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | -397     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 486      |
# |    time_elapsed     | 2104     |
# |    total_timesteps  | 1023229  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000611 |
# |    n_updates        | 243307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.13e+03 |
# |    ep_rew_mean      | -400     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 485      |
# |    time_elapsed     | 2144     |
# |    total_timesteps  | 1040905  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000787 |
# |    n_updates        | 247726   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | -389     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 485      |
# |    time_elapsed     | 2165     |
# |    total_timesteps  | 1050381  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000558 |
# |    n_updates        | 250095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | -388     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 483      |
# |    time_elapsed     | 2205     |
# |    total_timesteps  | 1067057  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000614 |
# |    n_updates        | 254264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | -377     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 483      |
# |    time_elapsed     | 2227     |
# |    total_timesteps  | 1076152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00032  |
# |    n_updates        | 256537   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | -376     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 482      |
# |    time_elapsed     | 2267     |
# |    total_timesteps  | 1092987  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00147  |
# |    n_updates        | 260746   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | -380     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 480      |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 1109438  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000783 |
# |    n_updates        | 264859   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | -379     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 479      |
# |    time_elapsed     | 2347     |
# |    total_timesteps  | 1126145  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000434 |
# |    n_updates        | 269036   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | -379     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 478      |
# |    time_elapsed     | 2387     |
# |    total_timesteps  | 1142679  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000381 |
# |    n_updates        | 273169   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | -389     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 477      |
# |    time_elapsed     | 2427     |
# |    total_timesteps  | 1160002  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00432  |
# |    n_updates        | 277500   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | -390     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 477      |
# |    time_elapsed     | 2457     |
# |    total_timesteps  | 1173485  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000445 |
# |    n_updates        | 280871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | -387     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 477      |
# |    time_elapsed     | 2490     |
# |    total_timesteps  | 1188117  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000241 |
# |    n_updates        | 284529   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | -381     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 476      |
# |    time_elapsed     | 2521     |
# |    total_timesteps  | 1201873  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00053  |
# |    n_updates        | 287968   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | -378     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 476      |
# |    time_elapsed     | 2561     |
# |    total_timesteps  | 1219749  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00027  |
# |    n_updates        | 292437   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | -375     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 475      |
# |    time_elapsed     | 2588     |
# |    total_timesteps  | 1231703  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000438 |
# |    n_updates        | 295425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | -369     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 475      |
# |    time_elapsed     | 2619     |
# |    total_timesteps  | 1244641  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000452 |
# |    n_updates        | 298660   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | -364     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 474      |
# |    time_elapsed     | 2649     |
# |    total_timesteps  | 1258329  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000462 |
# |    n_updates        | 302082   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | -352     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 474      |
# |    time_elapsed     | 2671     |
# |    total_timesteps  | 1267429  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000539 |
# |    n_updates        | 304357   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.65e+03 |
# |    ep_rew_mean      | -336     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 474      |
# |    time_elapsed     | 2682     |
# |    total_timesteps  | 1272439  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000954 |
# |    n_updates        | 305609   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.56e+03 |
# |    ep_rew_mean      | -326     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 474      |
# |    time_elapsed     | 2702     |
# |    total_timesteps  | 1281639  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000502 |
# |    n_updates        | 307909   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57e+03 |
# |    ep_rew_mean      | -326     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 473      |
# |    time_elapsed     | 2742     |
# |    total_timesteps  | 1299622  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000572 |
# |    n_updates        | 312405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.48e+03 |
# |    ep_rew_mean      | -315     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 473      |
# |    time_elapsed     | 2763     |
# |    total_timesteps  | 1308937  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000587 |
# |    n_updates        | 314734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.45e+03 |
# |    ep_rew_mean      | -311     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 473      |
# |    time_elapsed     | 2785     |
# |    total_timesteps  | 1319023  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000187 |
# |    n_updates        | 317255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.46e+03 |
# |    ep_rew_mean      | -312     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 473      |
# |    time_elapsed     | 2817     |
# |    total_timesteps  | 1333983  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000693 |
# |    n_updates        | 320995   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.42e+03 |
# |    ep_rew_mean      | -307     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 473      |
# |    time_elapsed     | 2847     |
# |    total_timesteps  | 1347436  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00229  |
# |    n_updates        | 324358   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | -303     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 473      |
# |    time_elapsed     | 2878     |
# |    total_timesteps  | 1361929  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00181  |
# |    n_updates        | 327982   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | -294     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 473      |
# |    time_elapsed     | 2901     |
# |    total_timesteps  | 1372625  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000239 |
# |    n_updates        | 330656   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | -295     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 473      |
# |    time_elapsed     | 2922     |
# |    total_timesteps  | 1382906  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000645 |
# |    n_updates        | 333226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | -291     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 473      |
# |    time_elapsed     | 2953     |
# |    total_timesteps  | 1397108  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000304 |
# |    n_updates        | 336776   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | -298     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 473      |
# |    time_elapsed     | 2985     |
# |    total_timesteps  | 1412560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000236 |
# |    n_updates        | 340639   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | -290     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 472      |
# |    time_elapsed     | 3010     |
# |    total_timesteps  | 1423790  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000331 |
# |    n_updates        | 343447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | -287     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 472      |
# |    time_elapsed     | 3040     |
# |    total_timesteps  | 1437237  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00089  |
# |    n_updates        | 346809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 472      |
# |    time_elapsed     | 3072     |
# |    total_timesteps  | 1451773  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.79e-05 |
# |    n_updates        | 350443   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | -271     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 472      |
# |    time_elapsed     | 3092     |
# |    total_timesteps  | 1460704  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000505 |
# |    n_updates        | 352675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | -260     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 472      |
# |    time_elapsed     | 3112     |
# |    total_timesteps  | 1469917  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 354979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    time_elapsed     | 3986     |
# |    total_timesteps  | 1848597  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000998 |
# |    n_updates        | 449649   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.84e+03 |
# |    ep_rew_mean      | -92.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 463      |
# |    time_elapsed     | 3998     |
# |    total_timesteps  | 1853848  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000728 |
# |    n_updates        | 450961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.79e+03 |
# |    ep_rew_mean      | -87.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 463      |
# |    time_elapsed     | 4003     |
# |    total_timesteps  | 1856226  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00109  |
# |    n_updates        | 451556   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71e+03 |
# |    ep_rew_mean      | -76.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 463      |
# |    time_elapsed     | 4017     |
# |    total_timesteps  | 1862395  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 453098   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | -68.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 463      |
# |    time_elapsed     | 4036     |
# |    total_timesteps  | 1870473  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 455118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.69e+03 |
# |    ep_rew_mean      | -73.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 463      |
# |    time_elapsed     | 4057     |
# |    total_timesteps  | 1879951  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000223 |
# |    n_updates        | 457487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | -83.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 463      |
# |    time_elapsed     | 4078     |
# |    total_timesteps  | 1889129  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00073  |
# |    n_updates        | 459782   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | -77.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 463      |
# |    time_elapsed     | 4083     |
# |    total_timesteps  | 1891194  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000511 |
# |    n_updates        | 460298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | -87.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 462      |
# |    time_elapsed     | 4116     |
# |    total_timesteps  | 1905580  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000906 |
# |    n_updates        | 463894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77e+03 |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 462      |
# |    time_elapsed     | 4142     |
# |    total_timesteps  | 1917045  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000839 |
# |    n_updates        | 466761   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.69e+03 |
# |    ep_rew_mean      | -72.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 462      |
# |    time_elapsed     | 4145     |
# |    total_timesteps  | 1918586  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000249 |
# |    n_updates        | 467146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | -68      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 462      |
# |    time_elapsed     | 4154     |
# |    total_timesteps  | 1922245  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000475 |
# |    n_updates        | 468061   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | -72.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 462      |
# |    time_elapsed     | 4171     |
# |    total_timesteps  | 1929935  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000718 |
# |    n_updates        | 469983   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.58e+03 |
# |    ep_rew_mean      | -59.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 462      |
# |    time_elapsed     | 4175     |
# |    total_timesteps  | 1931410  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000365 |
# |    n_updates        | 470352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.55e+03 |
# |    ep_rew_mean      | -54.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 462      |
# |    time_elapsed     | 4190     |
# |    total_timesteps  | 1938244  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000826 |
# |    n_updates        | 472060   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | -50.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 462      |
# |    time_elapsed     | 4198     |
# |    total_timesteps  | 1941618  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000626 |
# |    n_updates        | 472904   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | -50.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 462      |
# |    time_elapsed     | 4203     |
# |    total_timesteps  | 1943936  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000622 |
# |    n_updates        | 473483   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | -51.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 462      |
# |    time_elapsed     | 4215     |
# |    total_timesteps  | 1949187  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000825 |
# |    n_updates        | 474796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.55e+03 |
# |    ep_rew_mean      | -55.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 462      |
# |    time_elapsed     | 4226     |
# |    total_timesteps  | 1954162  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000592 |
# |    n_updates        | 476040   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | -51.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 462      |
# |    time_elapsed     | 4236     |
# |    total_timesteps  | 1958527  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000588 |
# |    n_updates        | 477131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | -51.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 462      |
# |    time_elapsed     | 4250     |
# |    total_timesteps  | 1964304  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000253 |
# |    n_updates        | 478575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | -49.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 462      |
# |    time_elapsed     | 4262     |
# |    total_timesteps  | 1969781  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000675 |
# |    n_updates        | 479945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.46e+03 |
# |    ep_rew_mean      | -40.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 462      |
# |    time_elapsed     | 4269     |
# |    total_timesteps  | 1972646  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000791 |
# |    n_updates        | 480661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.37e+03 |
# |    ep_rew_mean      | -27.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 461      |
# |    time_elapsed     | 4280     |
# |    total_timesteps  | 1977543  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000294 |
# |    n_updates        | 481885   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.36e+03 |
# |    ep_rew_mean      | -27.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 461      |
# |    time_elapsed     | 4285     |
# |    total_timesteps  | 1979589  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000296 |
# |    n_updates        | 482397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.36e+03 |
# |    ep_rew_mean      | -27.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 461      |
# |    time_elapsed     | 4298     |
# |    total_timesteps  | 1985084  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000184 |
# |    n_updates        | 483770   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.34e+03 |
# |    ep_rew_mean      | -24.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 461      |
# |    time_elapsed     | 4305     |
# |    total_timesteps  | 1988067  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000586 |
# |    n_updates        | 484516   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.34e+03 |
# |    ep_rew_mean      | -23.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 461      |
# |    time_elapsed     | 4309     |
# |    total_timesteps  | 1989952  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 484987   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.29e+03 |
# |    ep_rew_mean      | -18.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 461      |
# |    time_elapsed     | 4313     |
# |    total_timesteps  | 1991762  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000435 |
# |    n_updates        | 485440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.24e+03 |
# |    ep_rew_mean      | -11.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 461      |
# |    time_elapsed     | 4319     |
# |    total_timesteps  | 1994543  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 486135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.16e+03 |
# |    ep_rew_mean      | -1.28    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 461      |
# |    time_elapsed     | 4323     |
# |    total_timesteps  | 1996046  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000446 |
# |    n_updates        | 486511   |
# ----------------------------------

# %%
model.learn(total_timesteps=500000)
# Out:
# Logging to Training\Logs\DQN\DQN_15
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 1.38e+04  |
# |    ep_rew_mean      | -1.24e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 1783      |
# |    time_elapsed     | 31        |
# |    total_timesteps  | 55336     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.21      |
# |    n_updates        | 638833    |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.13e+03 |
# |    ep_rew_mean      | -574     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1646     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 57061    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000577 |
# |    n_updates        | 639265   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.28e+03 |
# |    ep_rew_mean      | -403     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1329     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 63332    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 640832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.45e+03 |
# |    ep_rew_mean      | -325     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1121     |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 71203    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000827 |
# |    n_updates        | 642800   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | -254     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1043     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 75660    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00125  |
# |    n_updates        | 643914   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | -219     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 967      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 81366    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00195  |
# |    n_updates        | 645341   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | -215     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 868      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 92071    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00141  |
# |    n_updates        | 648017   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 825      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 98804    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00276  |
# |    n_updates        | 649700   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 780      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 107855   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 651963   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 716      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 120560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000508 |
# |    n_updates        | 655139   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.85e+03 |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 696      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 125490   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00196  |
# |    n_updates        | 656372   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.71e+03 |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 681      |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 130285   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00351  |
# |    n_updates        | 657571   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.62e+03 |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 670      |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 135997   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 658999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46e+03 |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 667      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 137681   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000819 |
# |    n_updates        | 659420   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 651      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 147117   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00102  |
# |    n_updates        | 661779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | -141     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 637      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 156869   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000426 |
# |    n_updates        | 664217   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.45e+03 |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 624      |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 166572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000946 |
# |    n_updates        | 666642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 615      |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 171714   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00101  |
# |    n_updates        | 667928   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.29e+03 |
# |    ep_rew_mean      | -127     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 611      |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 174100   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000715 |
# |    n_updates        | 668524   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 601      |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 180257   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00057  |
# |    n_updates        | 670064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.18e+03 |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 597      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 182936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000723 |
# |    n_updates        | 670733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 594      |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 184851   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00145  |
# |    n_updates        | 671212   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 586      |
# |    time_elapsed     | 324      |
# |    total_timesteps  | 190129   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000783 |
# |    n_updates        | 672532   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | -99.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 577      |
# |    time_elapsed     | 339      |
# |    total_timesteps  | 195951   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000984 |
# |    n_updates        | 673987   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 566      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 204837   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 676209   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.54e+03 |
# |    ep_rew_mean      | -51.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 562      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 208981   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000822 |
# |    n_updates        | 677245   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | -67.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 549      |
# |    time_elapsed     | 405      |
# |    total_timesteps  | 222892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00069  |
# |    n_updates        | 680722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.65e+03 |
# |    ep_rew_mean      | -67.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 544      |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 228639   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000506 |
# |    n_updates        | 682159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | -64.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 540      |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 233347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000705 |
# |    n_updates        | 683336   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.59e+03 |
# |    ep_rew_mean      | -62.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 540      |
# |    time_elapsed     | 433      |
# |    total_timesteps  | 234209   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000544 |
# |    n_updates        | 683552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.58e+03 |
# |    ep_rew_mean      | -61.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 536      |
# |    time_elapsed     | 446      |
# |    total_timesteps  | 239507   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000615 |
# |    n_updates        | 684876   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.53e+03 |
# |    ep_rew_mean      | -55.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 533      |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 244738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000644 |
# |    n_updates        | 686184   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.53e+03 |
# |    ep_rew_mean      | -55.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 529      |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 251726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000607 |
# |    n_updates        | 687931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | -54.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 524      |
# |    time_elapsed     | 495      |
# |    total_timesteps  | 260284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00189  |
# |    n_updates        | 690070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.44e+03 |
# |    ep_rew_mean      | -44.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 522      |
# |    time_elapsed     | 507      |
# |    total_timesteps  | 265046   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000514 |
# |    n_updates        | 691261   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.48e+03 |
# |    ep_rew_mean      | -48      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 518      |
# |    time_elapsed     | 527      |
# |    total_timesteps  | 273712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000658 |
# |    n_updates        | 693427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | -50.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 514      |
# |    time_elapsed     | 547      |
# |    total_timesteps  | 281575   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 695393   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.59e+03 |
# |    ep_rew_mean      | -59      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 510      |
# |    time_elapsed     | 578      |
# |    total_timesteps  | 295377   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00196  |
# |    n_updates        | 698844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.67e+03 |
# |    ep_rew_mean      | -67.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 507      |
# |    time_elapsed     | 600      |
# |    total_timesteps  | 304260   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0021   |
# |    n_updates        | 701064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | -62.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 505      |
# |    time_elapsed     | 611      |
# |    total_timesteps  | 308926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000673 |
# |    n_updates        | 702231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | -65.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 501      |
# |    time_elapsed     | 635      |
# |    total_timesteps  | 318857   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000393 |
# |    n_updates        | 704714   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | -64.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 498      |
# |    time_elapsed     | 656      |
# |    total_timesteps  | 327380   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00173  |
# |    n_updates        | 706844   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | -62.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 496      |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 332199   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000644 |
# |    n_updates        | 708049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | -66.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 495      |
# |    time_elapsed     | 681      |
# |    total_timesteps  | 337528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00119  |
# |    n_updates        | 709381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | -63.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 494      |
# |    time_elapsed     | 690      |
# |    total_timesteps  | 341341   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000586 |
# |    n_updates        | 710335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | -66.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 492      |
# |    time_elapsed     | 703      |
# |    total_timesteps  | 346581   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 711645   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 490      |
# |    time_elapsed     | 723      |
# |    total_timesteps  | 355245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000446 |
# |    n_updates        | 713811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | -77.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 488      |
# |    time_elapsed     | 740      |
# |    total_timesteps  | 361959   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000895 |
# |    n_updates        | 715489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | -83.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 485      |
# |    time_elapsed     | 766      |
# |    total_timesteps  | 372284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00197  |
# |    n_updates        | 718070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | -77.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 484      |
# |    time_elapsed     | 778      |
# |    total_timesteps  | 377034   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 719258   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | -79.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 483      |
# |    time_elapsed     | 789      |
# |    total_timesteps  | 381345   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000915 |
# |    n_updates        | 720336   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | -68.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 481      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 386386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00113  |
# |    n_updates        | 721596   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.67e+03 |
# |    ep_rew_mean      | -72.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 478      |
# |    time_elapsed     | 825      |
# |    total_timesteps  | 395145   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00476  |
# |    n_updates        | 723786   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | -68.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 478      |
# |    time_elapsed     | 828      |
# |    total_timesteps  | 396300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 724074   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.67e+03 |
# |    ep_rew_mean      | -73.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 476      |
# |    time_elapsed     | 841      |
# |    total_timesteps  | 401240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00103  |
# |    n_updates        | 725309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | -77.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 475      |
# |    time_elapsed     | 862      |
# |    total_timesteps  | 409656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 727413   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | -77.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 474      |
# |    time_elapsed     | 873      |
# |    total_timesteps  | 414401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00268  |
# |    n_updates        | 728600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71e+03 |
# |    ep_rew_mean      | -78.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 472      |
# |    time_elapsed     | 893      |
# |    total_timesteps  | 422381   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000827 |
# |    n_updates        | 730595   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | -72.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 472      |
# |    time_elapsed     | 901      |
# |    total_timesteps  | 425946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00753  |
# |    n_updates        | 731486   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | -72.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 471      |
# |    time_elapsed     | 913      |
# |    total_timesteps  | 430555   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000502 |
# |    n_updates        | 732638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.58e+03 |
# |    ep_rew_mean      | -64.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 471      |
# |    time_elapsed     | 917      |
# |    total_timesteps  | 432136   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000932 |
# |    n_updates        | 733033   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | -66.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 469      |
# |    time_elapsed     | 939      |
# |    total_timesteps  | 441093   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00119  |
# |    n_updates        | 735273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.58e+03 |
# |    ep_rew_mean      | -65.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 467      |
# |    time_elapsed     | 968      |
# |    total_timesteps  | 453253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0017   |
# |    n_updates        | 738313   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.55e+03 |
# |    ep_rew_mean      | -61.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 466      |
# |    time_elapsed     | 982      |
# |    total_timesteps  | 458773   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00101  |
# |    n_updates        | 739693   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.54e+03 |
# |    ep_rew_mean      | -61.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 466      |
# |    time_elapsed     | 993      |
# |    total_timesteps  | 463321   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000475 |
# |    n_updates        | 740830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.46e+03 |
# |    ep_rew_mean      | -50.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 466      |
# |    time_elapsed     | 996      |
# |    total_timesteps  | 464760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 741189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.39e+03 |
# |    ep_rew_mean      | -40.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 466      |
# |    time_elapsed     | 999      |
# |    total_timesteps  | 465960   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00208  |
# |    n_updates        | 741489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.39e+03 |
# |    ep_rew_mean      | -42.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 465      |
# |    time_elapsed     | 1012     |
# |    total_timesteps  | 470924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000997 |
# |    n_updates        | 742730   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.43e+03 |
# |    ep_rew_mean      | -47.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 464      |
# |    time_elapsed     | 1036     |
# |    total_timesteps  | 480796   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000691 |
# |    n_updates        | 745198   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.48e+03 |
# |    ep_rew_mean      | -55.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 462      |
# |    time_elapsed     | 1056     |
# |    total_timesteps  | 489134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000248 |
# |    n_updates        | 747283   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.46e+03 |
# |    ep_rew_mean      | -52.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 462      |
# |    time_elapsed     | 1064     |
# |    total_timesteps  | 492478   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000434 |
# |    n_updates        | 748119   |
# ----------------------------------

# %%
env.close()

# %%
model.save(dqn_model_path)

# %%
evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# c:\Users\jahin\anaconda3\envs\myenv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-282.51501084417106, 410.1125634007472)

# %%
del model

# %%
model = PPO.load(baseline_path)

# %%
env = GameEnv()
env.reset()
model.set_env(env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=140000)
# Out:
# Logging to Training\Logs\Proximal_reward\PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 307      |
# |    ep_rew_mean     | 36.2     |
# | time/              |          |
# |    fps             | 334      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 41.9        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011869484 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.75        |
# |    n_updates            | 7280        |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 461         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.003075364 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.56        |
# |    n_updates            | 7290        |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 414         |
# |    ep_rew_mean          | 23.2        |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011886261 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.000253   |
# |    value_loss           | 40.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 520         |
# |    ep_rew_mean          | 9.56        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 5           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009119676 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64        |
# |    n_updates            | 7310        |
# |    policy_gradient_loss | -0.000949   |
# |    value_loss           | 7.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 6           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012890076 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83        |
# |    n_updates            | 7320        |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 32          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 396          |
# |    ep_rew_mean          | 24.5         |
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 7            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0047478387 |
# |    clip_fraction        | 0.0891       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.926       |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19           |
# |    n_updates            | 7330         |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 35.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 8           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017743677 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00299    |
# |    n_updates            | 7340        |
# |    policy_gradient_loss | 0.000253    |
# |    value_loss           | 0.345       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 501         |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 9           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013984585 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.629       |
# |    n_updates            | 7350        |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 9.32        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 501        |
# |    ep_rew_mean          | 10.1       |
# | time/                   |            |
# |    fps                  | 257        |
# |    iterations           | 10         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00563307 |
# |    clip_fraction        | 0.017      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.217      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.1       |
# |    n_updates            | 7360       |
# |    policy_gradient_loss | -0.00276   |
# |    value_loss           | 38.8       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 543          |
# |    ep_rew_mean          | 4.58         |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 11           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0073292837 |
# |    clip_fraction        | 0.27         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -4.17e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.071        |
# |    n_updates            | 7370         |
# |    policy_gradient_loss | 0.00357      |
# |    value_loss           | 0.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 573          |
# |    ep_rew_mean          | 3.65         |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 12           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0068704574 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.01         |
# |    n_updates            | 7380         |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 10.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | -3.11       |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 13          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015462197 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 7390        |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 11.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 646          |
# |    ep_rew_mean          | -8.06        |
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 14           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0072159246 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.653        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.171        |
# |    n_updates            | 7400         |
# |    policy_gradient_loss | 0.000776     |
# |    value_loss           | 30.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 646        |
# |    ep_rew_mean          | -8.06      |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 15         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00969575 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | -0.119     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 118        |
# |    n_updates            | 7410       |
# |    policy_gradient_loss | 0.00175    |
# |    value_loss           | 45.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 683         |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 16          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015752882 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0687      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0246     |
# |    n_updates            | 7420        |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 1.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 17          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013414128 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0602      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0748      |
# |    n_updates            | 7430        |
# |    policy_gradient_loss | 0.000839    |
# |    value_loss           | 4.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 730          |
# |    ep_rew_mean          | -21          |
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 18           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0045079794 |
# |    clip_fraction        | 0.0827       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 7440         |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 39.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 698         |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 19          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008133542 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.02        |
# |    n_updates            | 7450        |
# |    policy_gradient_loss | -0.00527    |
# |    value_loss           | 40.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 698         |
# |    ep_rew_mean          | -15.1       |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 20          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003503846 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.02        |
# |    n_updates            | 7460        |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 25.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 731         |
# |    ep_rew_mean          | -20.2       |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 21          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005546796 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0249      |
# |    n_updates            | 7470        |
# |    policy_gradient_loss | -0.000193   |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | -21.7       |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 22          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017683081 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0832      |
# |    n_updates            | 7480        |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | -21.7       |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 23          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002907523 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 7490        |
# |    policy_gradient_loss | -0.000473   |
# |    value_loss           | 46.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 744         |
# |    ep_rew_mean          | -21         |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 24          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012202786 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.000356   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0212      |
# |    n_updates            | 7500        |
# |    policy_gradient_loss | -0.00606    |
# |    value_loss           | 0.0725      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 731          |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 25           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0053490135 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.538        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.7         |
# |    n_updates            | 7510         |
# |    policy_gradient_loss | -0.00376     |
# |    value_loss           | 39.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 744         |
# |    ep_rew_mean          | -20.8       |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 26          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.002814399 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.355       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.22        |
# |    n_updates            | 7520        |
# |    policy_gradient_loss | 0.0006      |
# |    value_loss           | 7.58        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 716          |
# |    ep_rew_mean          | -16.4        |
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 27           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0062807696 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.9         |
# |    n_updates            | 7530         |
# |    policy_gradient_loss | -0.000282    |
# |    value_loss           | 29.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | -17.1        |
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 28           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0059063276 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.4         |
# |    n_updates            | 7540         |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 20.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 730         |
# |    ep_rew_mean          | -15.9       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 29          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015721742 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.54        |
# |    n_updates            | 7550        |
# |    policy_gradient_loss | -0.0046     |
# |    value_loss           | 5.75        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 725          |
# |    ep_rew_mean          | -14.4        |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 30           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0036517002 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 7560         |
# |    policy_gradient_loss | 0.000955     |
# |    value_loss           | 40.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 730          |
# |    ep_rew_mean          | -13.9        |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 31           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0055200555 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 7570         |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 16.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 751         |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 32          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.019196428 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.79        |
# |    n_updates            | 7580        |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 748         |
# |    ep_rew_mean          | -16.7       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 33          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012128385 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 7590        |
# |    policy_gradient_loss | 0.00394     |
# |    value_loss           | 37          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 753          |
# |    ep_rew_mean          | -16.4        |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 34           |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0073301764 |
# |    clip_fraction        | 0.0805       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.598        |
# |    n_updates            | 7600         |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 5.83         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 770         |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 35          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012672084 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.15        |
# |    n_updates            | 7610        |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 768         |
# |    ep_rew_mean          | -18         |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 36          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.019624773 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.00613     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 7620        |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 34.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 763         |
# |    ep_rew_mean          | -17.4       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 37          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008405702 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 7630        |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 39.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 777         |
# |    ep_rew_mean          | -19.6       |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 38          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.015239227 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.354       |
# |    n_updates            | 7640        |
# |    policy_gradient_loss | -0.00767    |
# |    value_loss           | 4.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 794         |
# |    ep_rew_mean          | -22.4       |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 39          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015921742 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.0576     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 7650        |
# |    policy_gradient_loss | 0.00274     |
# |    value_loss           | 39.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 817          |
# |    ep_rew_mean          | -25.6        |
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 40           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0077774953 |
# |    clip_fraction        | 0.132        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.9         |
# |    n_updates            | 7660         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 27           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 813         |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 41          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012948468 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0351      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.3        |
# |    n_updates            | 7670        |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 33          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 838         |
# |    ep_rew_mean          | -28.6       |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 42          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011789778 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43        |
# |    n_updates            | 7680        |
# |    policy_gradient_loss | -0.00719    |
# |    value_loss           | 27.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 848         |
# |    ep_rew_mean          | -29.6       |
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 43          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016002128 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.823       |
# |    n_updates            | 7690        |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | -33         |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 44          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009649903 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.68        |
# |    n_updates            | 7700        |
# |    policy_gradient_loss | -0.00862    |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 45          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010048799 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.7         |
# |    n_updates            | 7710        |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 879         |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 46          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.020039497 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.26        |
# |    n_updates            | 7720        |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 8.82        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -35.2      |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 47         |
# |    time_elapsed         | 397        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.00896628 |
# |    clip_fraction        | 0.0563     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.409      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.8       |
# |    n_updates            | 7730       |
# |    policy_gradient_loss | -0.00238   |
# |    value_loss           | 38.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 899        |
# |    ep_rew_mean          | -35.2      |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 48         |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.04165718 |
# |    clip_fraction        | 0.341      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.16       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.225      |
# |    n_updates            | 7740       |
# |    policy_gradient_loss | 0.0018     |
# |    value_loss           | 10.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 902         |
# |    ep_rew_mean          | -35.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 49          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.015796162 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 7750        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.882       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | -38.8       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 50          |
# |    time_elapsed         | 424         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.009577227 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.337       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.65        |
# |    n_updates            | 7760        |
# |    policy_gradient_loss | -0.000938   |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 922         |
# |    ep_rew_mean          | -38.8       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 51          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009415885 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0214      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.566       |
# |    n_updates            | 7770        |
# |    policy_gradient_loss | 0.00029     |
# |    value_loss           | 32.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 941         |
# |    ep_rew_mean          | -42.1       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 52          |
# |    time_elapsed         | 440         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.018297233 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.0183     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 7780        |
# |    policy_gradient_loss | -0.000228   |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | -45.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 53          |
# |    time_elapsed         | 449         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010376364 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 7790        |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 6.85        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 989        |
# |    ep_rew_mean          | -48.7      |
# | time/                   |            |
# |    fps                  | 241        |
# |    iterations           | 54         |
# |    time_elapsed         | 458        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.00932358 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.136      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.3       |
# |    n_updates            | 7800       |
# |    policy_gradient_loss | -0.00296   |
# |    value_loss           | 32.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -51.8       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 55          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010614265 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.0842      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.387       |
# |    n_updates            | 7810        |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 28.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -55.2       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 56          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010509788 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 3.87e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.748       |
# |    n_updates            | 7820        |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -55.3       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 57          |
# |    time_elapsed         | 484         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.008480541 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.197      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 7830        |
# |    policy_gradient_loss | 0.0013      |
# |    value_loss           | 25          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.06e+03     |
# |    ep_rew_mean          | -58.5        |
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 58           |
# |    time_elapsed         | 492          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0077713258 |
# |    clip_fraction        | 0.0845       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.00897     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 7840         |
# |    policy_gradient_loss | -0.000851    |
# |    value_loss           | 15.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -61.8       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 59          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.013852305 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 7850        |
# |    policy_gradient_loss | 0.000455    |
# |    value_loss           | 25          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -56.5       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 60          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.023897704 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 7860        |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 43.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -56.5       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 61          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.009216544 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.04        |
# |    n_updates            | 7870        |
# |    policy_gradient_loss | -0.00623    |
# |    value_loss           | 24          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -57.7       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 62          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.019844383 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -4.65e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0385      |
# |    n_updates            | 7880        |
# |    policy_gradient_loss | 0.00167     |
# |    value_loss           | 0.0618      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.08e+03   |
# |    ep_rew_mean          | -58.6      |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 63         |
# |    time_elapsed         | 536        |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.00893803 |
# |    clip_fraction        | 0.0777     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.56       |
# |    n_updates            | 7890       |
# |    policy_gradient_loss | -0.00118   |
# |    value_loss           | 22.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -58.6       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 64          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.011964238 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 7900        |
# |    policy_gradient_loss | -0.00347    |
# |    value_loss           | 8.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -61.2       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 65          |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.013348234 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.038       |
# |    n_updates            | 7910        |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 0.0684      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | -49.2       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 66          |
# |    time_elapsed         | 562         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.009488966 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 7920        |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 25.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 994          |
# |    ep_rew_mean          | -46.1        |
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 67           |
# |    time_elapsed         | 571          |
# |    total_timesteps      | 137216       |
# | train/                  |              |
# |    approx_kl            | 0.0040176874 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 7930         |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 51.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -50.1       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 68          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.015312087 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.755       |
# |    n_updates            | 7940        |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 4.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -50.1       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 69          |
# |    time_elapsed         | 589         |
# |    total_timesteps      | 141312      |
# | train/                  |             |
# |    approx_kl            | 0.016509015 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 7950        |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 37.1        |
# -----------------------------------------

# %%
evaluate_policy(model=model, env=env, n_eval_episodes=30)
# Out:
# c:\Users\jahin\anaconda3\envs\myenv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-54.165003379620615, 312.1697359717535)

# %%
env.close()

# %%
# %tensorboard
