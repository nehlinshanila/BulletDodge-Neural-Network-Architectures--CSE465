# %%
import numpy as np

# %%
class Agent:
    def __init__(self, agent_name, agent_index):
        self.index = agent_index
        self.agent = agent_name
        self.health = None
        self.isHit = False
        self.move = True
        self.movement_speed = 1.00
        self.previous_position = np.array([0, 0], dtype=np.float32)
        self.current_position = None
        self.same_position = False
        self.current_step = 0
        self.action = None
        pass

    def agent_action(self, action):

        pass

    def agent_reset(self, width, height):
        padding = 30
        self.current_position = np.array(
            [np.random.uniform(30, width - padding), np.random.uniform(30, width - padding)], dtype=np.float32)

    def step_update(self, action, range_x, range_y):

        if action == 0:
            self.current_position[0] -= self.movement_speed
        elif action == 1:
            self.current_position[0] += self.movement_speed
        elif action == 2:
            self.current_position[1] -= self.movement_speed
        elif action == 3:
            self.current_position[1] += self.movement_speed
        
        self.current_position[0] = np.clip(self.current_position[0], 0, range_x)
        self.current_position[1] = np.clip(self.current_position[1], 0, range_y)

# %%
from gymnasium.spaces import Discrete, Box, MultiDiscrete
from gymnasium import Env
import numpy as np
import pygame
import time

# %%
start = time.time()
time.sleep(1)
end = time.time()

print(end - start)
# Out:
# 1.0012104511260986

# %%
class GameEnv(Env):
    def __init__(self, screen_width=400, screen_height=400, render_mode='human'):
        super(GameEnv, self).__init__()

        # defining the screen dimension for render purpose
        self.screen_width = screen_width
        self.screen_height = screen_height
        self.render_mode = render_mode

        # defining the observation and action spaces for all the agents
        
        self.observation_space = Box(low=np.array([0, 0, 0, 0], dtype=np.float32),
                                    high=np.array([self.screen_width, self.screen_height, self.screen_width, self.screen_height], dtype=np.float32),
                                    dtype=np.float32)

        # the pygame window should be initialized in the render function

        # setting the total number of agent
        
        self.number_of_prey = 1
        self.number_of_predator = 1
        self.prey_agent = None
        self.predator_agent = None
        self.predator_i_position = None
        self.initial_distance = None
        self.current_distance = None
        self.predator_total_reward = 0
        self.number_of_agents = self.number_of_prey + self.number_of_prey

        # defining the action space based on total number of predator and prey
        self.action_space = Discrete(4)


        # setting the total number of obstacles
        self.total_obstacles = None

        # keeping a counter to save the total steps
        self.total_steps = 0

        # initializing the pygame
        pygame.init()

        # setting the screen size
        self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
        pygame.display.set_caption('Multi Agent Environment(simple)')
        
        # keep the track of time of the rendering
        self.clock = pygame.time.Clock()

        # *it is set in milisec format (time is sec is time/1000)
        self.total_running_time = 10

        # start the tick timer
        self.start_time = 0
        # print(f'start  time: {self.start_time}')

        # initializing the font
        pygame.font.init()
        self.font = pygame.font.Font(None, 18)

    # this function rerturns the value of the action into 2 digits 
    # if the action_space.sample() gives 1 digit number
    # * if  the number is 3 it will return 03 
    # * if  the number is 14 then it will return 14
    def expand_action_digit(self, action):

        # this basically checks the number if it has 1 then fills the rest with 0
        # if the number is 2 digits then it stays the same
        action = str(action).zfill(2)
        prey_action = int(action[0]) % 4
        predator_action = int(action[1]) % 4
        return prey_action, predator_action
        

    # this method will initialize the number of agents
    # ! this must be called from outside
    def agent_init(self):

        prey_agents = Agent('prey', 0)

        predator_agents = Agent('predator', 0)

        self.prey_agent = prey_agents
        self.predator_agent = predator_agents
        

    # this function is used to explicitly set the number of agents
    # ! this needs to be called from outside
    def set_agent_number(self, prey_number, predator_number):
        self.number_of_predator = predator_number
        self.number_of_prey = prey_number

    # the usual reset function
    def reset(self, seed=0):
        self.start_time = time.time()
        
        self.agent_init()

        self.total_steps = 0
        self.predator_total_reward = 0

        prey = self.prey_agent
        predator = self.predator_agent

        # for prey in self.prey_agents:
        prey.agent_reset(width=self.screen_width, height=self.screen_height)
        # observation.append([prey.index, prey.agent, prey.current_position])

        # for predator in self.predator_agents:
        predator.agent_reset(width=self.screen_width, height=self.screen_height)
        # observation.append([predator.index, predator.agent, predator.current_position])
        
        # setting the predator and prey to their initial position
        self.prey_agent = prey
        self.predator_agent = predator

        # setting the initial position of predator for reward
        self.predator_i_position = self.predator_agent.current_position
        
        # calculating the initial distance of 2 agents
        direction = self.predator_agent.current_position - self.prey_agent.current_position
        self.initial_distance = np.linalg.norm(direction)

        # observation :
        # all the variable values inside the obsercation space needs to be sent inside the observation variable
        observation = np.concatenate([self.prey_agent.current_position, self.predator_agent.current_position])
        return observation, seed

    # the step function
    # this function is called for every timesteps
    # this function updates the actions or states of agents in the env
    # this function is called default by the algorithms of all sorts
    # * it returns observation, reward, done, truncated, info
    # * any game policy change can be done here
    # * reward must be set here
    def step(self, action):
        
        # initializing the return variables
        done = False
        reward = 0
        truncated = False
        info = {}
        current_time = time.time()
        # print(f'current time: {current_time}')
        # when ever the step is starting set the start time
        # if self.total_steps == 0:
        #     self.start_time = pygame.time.get_ticks()
        # else:
        #     current_time = pygame.time.get_ticks()

        elapsed_time = current_time - self.start_time
        # print(f'elapsed time: {elapsed_time}')
        # handles the pygame window event when closing
        # !if the window still crashes pygame.event needs to be managed properly
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                done = True
                pygame.quit()
        
        # print(f'action: {action}')
        # *the actions are split as required
        # prey_action, predator_action = self.expand_action_digit(action)
        predator_action = action
        predator = self.predator_agent
        # print(f'prey: {prey_action}, predator: {predator_action}')
                

        # print(f'predator_{predator.index} = action:{action} current_position: {predator.current_position}')
        predator.step_update(action=predator_action, range_x=self.screen_width - 10, range_y=self.screen_height - 10)
        # print(f'predator_{predator.index}: new_position: {predator.current_position}')
            
        # !observation.append({'index': predator.index, 'name': predator.agent, 'position': predator.current_position})
        # observation = self.predator_agent.current_position
        observation = np.concatenate([self.prey_agent.current_position, self.predator_agent.current_position])

        # print(f'observation: {self.predator_agent.current_position}')
        self.total_steps += 1

        direction = self.predator_agent.current_position - self.prey_agent.current_position

        # Calculate the distance between the centers of the two dots
        distance_between_centers = np.linalg.norm(direction)
        self.current_distance = distance_between_centers

        # check everystep if the distance of two agents are:
        # greater than  initial distance?  
        # yes: -reward
        # no: +reward

        if distance_between_centers > self.initial_distance:
            reward -= 0.06
        else:
            reward += 0.01
            
        # Check if there is a collision (distance <= sum of radii)
        if elapsed_time <= self.total_running_time:
            if distance_between_centers <= 20:
                reward += 40
                done = True
                    # pygame.quit()
                    # self.close()
            # if self.total_steps == 30000:
            #     done = True
        else:
            done = True
            reward -= 20
                # pygame.quit()
                # self.close()

        # print(self.total_steps)
        self.render()
        # it will update the total reward everystep
        self.predator_total_reward = reward

        return observation, reward, done, _, info
        

    def render(self):
        if self.render_mode == 'human':
            screen = self.screen

            # clear screen
            screen.fill((255, 255, 255))
            prey = self.prey_agent
            pos_x, pos_y = prey.current_position
            prey_radius = 10
            pygame.draw.circle(screen, (0, 0, 255), (int(pos_x), int(pos_y)), prey_radius)

            predator = self.predator_agent
            pos_x, pos_y = predator.current_position
            predator_radius = 10

            pygame.draw.circle(screen, (255, 0, 0), (int(pos_x), int(pos_y)), predator_radius)

            text_surface = self.font.render(f"Reward: {self.predator_total_reward: .5f} initial distance: {self.initial_distance: .2f} current_distance:{self.current_distance: .2f}", True, (0, 0, 0))

            text_rect = text_surface.get_rect()

            text_rect.center = (self.screen_width - 200, 10)

            self.screen.blit(text_surface, text_rect)

            pygame.display.update()

    def close(self):
        pygame.quit()

# %%
env = GameEnv()
env.reset()
env.step(1)
env.render()

# %%
env.close()

# %% [markdown]
# Testing the environment

# %%
env = GameEnv()
for i in range(0, 5):
    done = False

    # env.agent_init()
    env.reset()
    total_reward = 0
    while not done:
        action = env.action_space.sample()
        obs, reward, done, _, _ = env.step(action)
        # total_reward += reward
    print(f'total reward: {reward}')
    print(f'Number of steps: {env.total_steps}')
        # env.render()
# Out:
# total reward: -19.99
# Number of steps: 30604
# total reward: -20.06
# Number of steps: 32743
# total reward: 40.01
# Number of steps: 622
# total reward: -20.06
# Number of steps: 35572
# total reward: -20.06
# Number of steps: 33556

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
env.close()

# %%
env = GameEnv()

env.reset()
# Out:
# (array([283.04483 , 302.16772 , 125.367615,  72.67946 ], dtype=float32), 0)

# %%
# env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')

# %%
env = GameEnv()

env.reset()
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=100000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_16
# -----------------------------
# | time/              |      |
# |    fps             | 353  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.61e+03    |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009640449 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0167      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.6e+03     |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015927419 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0478      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.118       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 1.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.6e+03     |
# |    ep_rew_mean          | -88         |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 4           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009355174 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.815       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.6e+03     |
# |    ep_rew_mean          | -88         |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 5           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011611763 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0296     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.56e+03    |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 6           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014331505 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0393     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.0184      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.57e+03    |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 7           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008196421 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0467      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 0.193       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.58e+03    |
# |    ep_rew_mean          | -94.2       |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 8           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011679589 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.339      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0912      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00601    |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.58e+03    |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 9           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014824345 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 1.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.58e+03    |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 10          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010333714 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0294      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0411      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.56e+03    |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 11          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008049956 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 0.00169     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.57e+03    |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 12          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012054738 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0246      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 0.116       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.57e+03     |
# |    ep_rew_mean          | -125         |
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 13           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0045656525 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.163        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 0.849        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.55e+03  |
# |    ep_rew_mean          | -128      |
# | time/                   |           |
# |    fps                  | 248       |
# |    iterations           | 14        |
# |    time_elapsed         | 115       |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0095287 |
# |    clip_fraction        | 0.0778    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.27     |
# |    explained_variance   | 0.485     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.036     |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -0.00133  |
# |    value_loss           | 0.873     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.54e+03    |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 15          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018508714 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0378     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0297      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0086     |
# |    value_loss           | 0.952       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.54e+03    |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 16          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008112671 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0208     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.52e+03    |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 17          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011634768 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0912      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0395     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00699    |
# |    value_loss           | 0.00031     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 18          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012534788 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.379      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 0.163       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 19          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016924687 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00344    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0513      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.5e+03     |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 20          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010441158 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 0.89        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.5e+03    |
# |    ep_rew_mean          | -131       |
# | time/                   |            |
# |    fps                  | 242        |
# |    iterations           | 21         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00961582 |
# |    clip_fraction        | 0.0886     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.145      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00169   |
# |    value_loss           | 0.701      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.49e+03    |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 22          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012840588 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.448       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 0.776       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.49e+03    |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 23          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016162416 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00548    |
# |    value_loss           | 0.799       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48e+03    |
# |    ep_rew_mean          | -126        |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 24          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006413071 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00442     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 0.0158      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48e+03    |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 25          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011488392 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0183      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 0.172       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48e+03    |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 26          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.020086013 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0538     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 1.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.47e+03    |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 27          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009798955 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.804       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 0.919       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.47e+03    |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 28          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009868906 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0964      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0658      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.47e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 29          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008902801 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0107     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.168       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00773    |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.47e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 30          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.015507694 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0312      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 1.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.46e+03    |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 31          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.021361073 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00387     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00948    |
# |    value_loss           | 0.00625     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.46e+03    |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 32          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013799124 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0287     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45e+03    |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 33          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009619066 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.00357     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 1.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 34          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009234954 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45e+03    |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 35          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.053626385 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 1.18        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.45e+03     |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 36           |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0126054855 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 0.997        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45e+03    |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 37          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006953605 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.806       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 0.931       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 38          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010478129 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0228     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 0.0181      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 39          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.025439814 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0488     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 0.124       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.44e+03   |
# |    ep_rew_mean          | -115       |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 40         |
# |    time_elapsed         | 346        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01355393 |
# |    clip_fraction        | 0.157      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.317      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.815      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0088    |
# |    value_loss           | 0.885      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 41          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009055173 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0325      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.44e+03   |
# |    ep_rew_mean          | -116       |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 42         |
# |    time_elapsed         | 364        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00846024 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.0733     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0408     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00312   |
# |    value_loss           | 0.988      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.44e+03    |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 43          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013206237 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.64        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 0.978       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.43e+03   |
# |    ep_rew_mean          | -114       |
# | time/                   |            |
# |    fps                  | 235        |
# |    iterations           | 44         |
# |    time_elapsed         | 382        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04687744 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | -0.0989    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.657      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00939   |
# |    value_loss           | 1          |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.43e+03     |
# |    ep_rew_mean          | -114         |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 45           |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0073104305 |
# |    clip_fraction        | 0.0774       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0131      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00312     |
# |    value_loss           | 0.933        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.43e+03     |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 46           |
# |    time_elapsed         | 400          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0057636863 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.0474      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0154       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 0.000756     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.43e+03    |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 47          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014805217 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0449      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.43e+03    |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 48          |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011198959 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 0.862       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.43e+03    |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 49          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008690668 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 0.931       |
# -----------------------------------------

# %%
model.learn(total_timesteps=300000)
# Out:
# Logging to Training\Logs\PPO_18
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 41.5     |
# | time/              |          |
# |    fps             | 303      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | -59.3       |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008069878 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.826       |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 4.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.56e+03    |
# |    ep_rew_mean          | -38.9       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011791197 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0294      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.517       |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.42e+03    |
# |    ep_rew_mean          | -22.5       |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009896422 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00555     |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 0.922       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+03     |
# |    ep_rew_mean          | -41.2        |
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 5            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0059284493 |
# |    clip_fraction        | 0.0601       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.111        |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00828     |
# |    value_loss           | 5.76         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -39.6       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 6           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014135124 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0305      |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 1.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -39.6       |
# | time/                   |             |
# |    fps                  | 234         |
# |    iterations           | 7           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009913366 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0815      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55        |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.79e+03    |
# |    ep_rew_mean          | -40.8       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 8           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010076575 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87e+03    |
# |    ep_rew_mean          | -49.7       |
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 9           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006532142 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00921     |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 0.323       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | -44.3        |
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 10           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0072300043 |
# |    clip_fraction        | 0.061        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0813       |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 1.62         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | -50.9      |
# | time/                   |            |
# |    fps                  | 236        |
# |    iterations           | 11         |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01312652 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.231      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.99       |
# |    n_updates            | 1080       |
# |    policy_gradient_loss | -0.00577   |
# |    value_loss           | 2.01       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04e+03    |
# |    ep_rew_mean          | -58.9       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 12          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011320256 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0643     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.913       |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 1.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.04e+03    |
# |    ep_rew_mean          | -58.9       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 13          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008399125 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 1.82        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05e+03   |
# |    ep_rew_mean          | -65.2      |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 14         |
# |    time_elapsed         | 120        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01559807 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.908      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0181    |
# |    n_updates            | 1110       |
# |    policy_gradient_loss | -0.0044    |
# |    value_loss           | 0.0372     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | -72.5       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 15          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010803271 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 0.149       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -67.2       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 16          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010069626 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+03    |
# |    ep_rew_mean          | -73.2       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 17          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016750164 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0459      |
# |    n_updates            | 1140        |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 1.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.15e+03     |
# |    ep_rew_mean          | -68.9        |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 18           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0030523553 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.597        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0351       |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 0.723        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.15e+03     |
# |    ep_rew_mean          | -68.9        |
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 19           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0053692535 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.463        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45         |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | -0.00741     |
# |    value_loss           | 1.7          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.16e+03    |
# |    ep_rew_mean          | -64.9       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 20          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007718387 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00872    |
# |    value_loss           | 0.0246      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19e+03    |
# |    ep_rew_mean          | -61.2       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 21          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.039494187 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2e+03     |
# |    ep_rew_mean          | -57.9       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 22          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008117992 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.63        |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22e+03    |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 23          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010039337 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0706      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.064       |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 1.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22e+03    |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 24          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.030463476 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0447      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.475       |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.23e+03    |
# |    ep_rew_mean          | -52.1       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 25          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014624889 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 0.00694     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.24e+03   |
# |    ep_rew_mean          | -49.7      |
# | time/                   |            |
# |    fps                  | 239        |
# |    iterations           | 26         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01299837 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.459      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0294    |
# |    n_updates            | 1230       |
# |    policy_gradient_loss | -0.021     |
# |    value_loss           | 0.206      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26e+03    |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 27          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008168688 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.179       |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 0.943       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.27e+03    |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 28          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009496485 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.852       |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 1.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.28e+03    |
# |    ep_rew_mean          | -55.8       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 29          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.005971403 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | 1.3e-05     |
# |    value_loss           | 1.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.2e+03      |
# |    ep_rew_mean          | -52.2        |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 30           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0103750955 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.256        |
# |    n_updates            | 1270         |
# |    policy_gradient_loss | -0.000707    |
# |    value_loss           | 1.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21e+03    |
# |    ep_rew_mean          | -54.3       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 31          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010239242 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.01        |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 3.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+03    |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 32          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.014474386 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 1.28        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.09e+03   |
# |    ep_rew_mean          | -52.1      |
# | time/                   |            |
# |    fps                  | 237        |
# |    iterations           | 33         |
# |    time_elapsed         | 284        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01239193 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0535     |
# |    n_updates            | 1300       |
# |    policy_gradient_loss | -0.00594   |
# |    value_loss           | 4.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1e+03     |
# |    ep_rew_mean          | -54.8       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 34          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008838002 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 4.59        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05e+03   |
# |    ep_rew_mean          | -52        |
# | time/                   |            |
# |    fps                  | 238        |
# |    iterations           | 35         |
# |    time_elapsed         | 300        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01620988 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0288     |
# |    n_updates            | 1320       |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 0.929      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 36          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005903655 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00477    |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 2.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.09e+03     |
# |    ep_rew_mean          | -53.3        |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 37           |
# |    time_elapsed         | 316          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0059200143 |
# |    clip_fraction        | 0.0846       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.314        |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00448     |
# |    value_loss           | 2.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09e+03    |
# |    ep_rew_mean          | -53.3       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 38          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017304543 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.27        |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.858       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.1e+03     |
# |    ep_rew_mean          | -51.7       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 39          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.021294879 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.314       |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.035      |
# |    value_loss           | 0.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13e+03    |
# |    ep_rew_mean          | -53.6       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 40          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015493519 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00659    |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 0.202       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+03     |
# |    ep_rew_mean          | -56.2        |
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 41           |
# |    time_elapsed         | 349          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0057545053 |
# |    clip_fraction        | 0.0511       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.833        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 0.974        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 42          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009049743 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00578    |
# |    value_loss           | 1.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 43          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011775894 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0376      |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -53.2       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 44          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.024249945 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0636     |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 0.0535      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 45          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013579387 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00629     |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.158       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+03     |
# |    ep_rew_mean          | -52.3        |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 46           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0046346867 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.713        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.54         |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 5.45         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14e+03   |
# |    ep_rew_mean          | -52.3      |
# | time/                   |            |
# |    fps                  | 240        |
# |    iterations           | 47         |
# |    time_elapsed         | 399        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01925914 |
# |    clip_fraction        | 0.29       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.169      |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | -0.0162    |
# |    value_loss           | 2.73       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.14e+03    |
# |    ep_rew_mean          | -51.1       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 48          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016301503 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0227     |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.0841      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.14e+03     |
# |    ep_rew_mean          | -49.9        |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 49           |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0069332523 |
# |    clip_fraction        | 0.0676       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00487     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | 0.000317     |
# |    value_loss           | 0.146        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.15e+03     |
# |    ep_rew_mean          | -48.8        |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 50           |
# |    time_elapsed         | 426          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0068433974 |
# |    clip_fraction        | 0.0805       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.0468      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.415        |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | -0.000686    |
# |    value_loss           | 1.81         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -51         |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 51          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.018326607 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.618       |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | -0.00777    |
# |    value_loss           | 1.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.13e+03    |
# |    ep_rew_mean          | -48.8       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 52          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009515427 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.149      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0303      |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 1.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11e+03    |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 53          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009357101 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.206       |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 3.46        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.12e+03     |
# |    ep_rew_mean          | -45          |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 54           |
# |    time_elapsed         | 462          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0045429952 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 4.14         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -44.1       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 55          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010461706 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.19        |
# |    n_updates            | 1520        |
# ...
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 5.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -17.4       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 130         |
# |    time_elapsed         | 1091        |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.013020697 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0203      |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.0085     |
# |    value_loss           | 0.873       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12e+03   |
# |    ep_rew_mean          | -19        |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 131        |
# |    time_elapsed         | 1099       |
# |    total_timesteps      | 268288     |
# | train/                  |            |
# |    approx_kl            | 0.02026275 |
# |    clip_fraction        | 0.41       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0695    |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | -0.0288    |
# |    value_loss           | 0.0288     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -19         |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 132         |
# |    time_elapsed         | 1108        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.010958642 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0234      |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.000549   |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -17.6       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 133         |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.011340131 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0675      |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00663    |
# |    value_loss           | 1.26        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14e+03   |
# |    ep_rew_mean          | -19.4      |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 134        |
# |    time_elapsed         | 1125       |
# |    total_timesteps      | 274432     |
# | train/                  |            |
# |    approx_kl            | 0.01513205 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.143      |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | -0.0093    |
# |    value_loss           | 2.49       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -18.2       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 135         |
# |    time_elapsed         | 1133        |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.009482797 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.229       |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 1.31        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.13e+03     |
# |    ep_rew_mean          | -16.4        |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 136          |
# |    time_elapsed         | 1141         |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0071854293 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.91         |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 2.45         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -16.8       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 137         |
# |    time_elapsed         | 1150        |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.007208932 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0322      |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 3.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -15.8       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 138         |
# |    time_elapsed         | 1157        |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.017141681 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.963       |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 1.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18e+03    |
# |    ep_rew_mean          | -16.1       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 139         |
# |    time_elapsed         | 1166        |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.015534319 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 1.52        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.18e+03     |
# |    ep_rew_mean          | -16.1        |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 140          |
# |    time_elapsed         | 1173         |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0146161895 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.351        |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 3.62         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17e+03    |
# |    ep_rew_mean          | -14.7       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 141         |
# |    time_elapsed         | 1181        |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.007947721 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0354      |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 0.0706      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2e+03     |
# |    ep_rew_mean          | -15         |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 142         |
# |    time_elapsed         | 1189        |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.010736465 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.00277    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.149       |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.2e+03     |
# |    ep_rew_mean          | -16.8       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 143         |
# |    time_elapsed         | 1198        |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.011809352 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.412       |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 1.66        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | -15.2      |
# | time/                   |            |
# |    fps                  | 244        |
# |    iterations           | 144        |
# |    time_elapsed         | 1208       |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.01574742 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | -0.136     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.01       |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.00673   |
# |    value_loss           | 1.56       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | -16.7      |
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 145        |
# |    time_elapsed         | 1217       |
# |    total_timesteps      | 296960     |
# | train/                  |            |
# |    approx_kl            | 0.00975528 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.178      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0577     |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | 0.00093    |
# |    value_loss           | 1.7        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17e+03    |
# |    ep_rew_mean          | -14.9       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 146         |
# |    time_elapsed         | 1225        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.008937624 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 1.5         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.17e+03     |
# |    ep_rew_mean          | -13.4        |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 147          |
# |    time_elapsed         | 1234         |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0071119308 |
# |    clip_fraction        | 0.0702       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.0172      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.69         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 6.39         |
# ------------------------------------------

# %%
model.learn(total_timesteps=300000)
# Out:
# Logging to Training\Logs\PPO_19
# -----------------------------
# | time/              |      |
# |    fps             | 343  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.57e+03    |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.023100622 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0367     |
# |    n_updates            | 2460        |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.0222      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.58e+03    |
# |    ep_rew_mean          | -80         |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012050085 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.36        |
# |    n_updates            | 2470        |
# |    policy_gradient_loss | -0.00527    |
# |    value_loss           | 1.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | -35        |
# | time/                   |            |
# |    fps                  | 264        |
# |    iterations           | 4          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.03855518 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.0234     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.723      |
# |    n_updates            | 2480       |
# |    policy_gradient_loss | -0.00467   |
# |    value_loss           | 1.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.35e+03    |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 5           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006513889 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00244    |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 5.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03e+03    |
# |    ep_rew_mean          | -35.9       |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 6           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015235561 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.158      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0524      |
# |    n_updates            | 2500        |
# |    policy_gradient_loss | -0.000481   |
# |    value_loss           | 1.5         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.03e+03     |
# |    ep_rew_mean          | -35.9        |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 7            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0120328665 |
# |    clip_fraction        | 0.0736       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98         |
# |    n_updates            | 2510         |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 5.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | -30.6       |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 8           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013945153 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 2520        |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.318       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | -46.8      |
# | time/                   |            |
# |    fps                  | 258        |
# |    iterations           | 9          |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01244967 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0182    |
# |    n_updates            | 2530       |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 0.273      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | -59.9      |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 10         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01296582 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.0794     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0705     |
# |    n_updates            | 2540       |
# |    policy_gradient_loss | 0.000922   |
# |    value_loss           | 1.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19e+03    |
# |    ep_rew_mean          | -53.5       |
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 11          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011888179 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 2550        |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 1.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | -48.2      |
# | time/                   |            |
# |    fps                  | 251        |
# |    iterations           | 12         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.03495984 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.64       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0366     |
# |    n_updates            | 2560       |
# |    policy_gradient_loss | -0.00856   |
# |    value_loss           | 2.1        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22e+03    |
# |    ep_rew_mean          | -48.2       |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 13          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013397425 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0203     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 2570        |
# |    policy_gradient_loss | -0.00146    |
# |    value_loss           | 1.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.22e+03    |
# |    ep_rew_mean          | -54.4       |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 14          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019008458 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0927      |
# |    n_updates            | 2580        |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21e+03    |
# |    ep_rew_mean          | -45.5       |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 15          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015209438 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 2590        |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.248       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -36.2       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 16          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007166533 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.518       |
# |    n_updates            | 2600        |
# |    policy_gradient_loss | -0.000568   |
# |    value_loss           | 3.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -39.7       |
# | time/                   |             |
# |    fps                  | 240         |
# |    iterations           | 17          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015074679 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01        |
# |    n_updates            | 2610        |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+03    |
# |    ep_rew_mean          | -28.9       |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 18          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012418551 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 2620        |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 2           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86e+03    |
# |    ep_rew_mean          | -25.1       |
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 19          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017135618 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 2630        |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.86e+03     |
# |    ep_rew_mean          | -23.9        |
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 20           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0134017235 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.047       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0695       |
# |    n_updates            | 2640         |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 3.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87e+03    |
# |    ep_rew_mean          | -22.8       |
# | time/                   |             |
# |    fps                  | 232         |
# |    iterations           | 21          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014690351 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.65        |
# |    n_updates            | 2650        |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.74e+03    |
# |    ep_rew_mean          | -17.4       |
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 22          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020549864 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 2660        |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 4.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+03    |
# |    ep_rew_mean          | -14.5       |
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 23          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009083023 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 2670        |
# |    policy_gradient_loss | -0.000713   |
# |    value_loss           | 11.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.71e+03   |
# |    ep_rew_mean          | -14        |
# | time/                   |            |
# |    fps                  | 227        |
# |    iterations           | 24         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00794025 |
# |    clip_fraction        | 0.082      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.309      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.108      |
# |    n_updates            | 2680       |
# |    policy_gradient_loss | -0.00273   |
# |    value_loss           | 6.82       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+03   |
# |    ep_rew_mean          | -13.7      |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 25         |
# |    time_elapsed         | 226        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01806755 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.146      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.93       |
# |    n_updates            | 2690       |
# |    policy_gradient_loss | -0.00154   |
# |    value_loss           | 2.08       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.69e+03    |
# |    ep_rew_mean          | -11.3       |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 26          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013644313 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 2700        |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 2.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.7e+03     |
# |    ep_rew_mean          | -11         |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 27          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010215667 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.687       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 2710        |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 5.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+03    |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 28          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009812546 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0651      |
# |    n_updates            | 2720        |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 1.98        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.69e+03   |
# |    ep_rew_mean          | -8.69      |
# | time/                   |            |
# |    fps                  | 222        |
# |    iterations           | 29         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02557156 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.000576   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.123      |
# |    n_updates            | 2730       |
# |    policy_gradient_loss | 0.00605    |
# |    value_loss           | 2.32       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.7e+03     |
# |    ep_rew_mean          | -8.43       |
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 30          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014302064 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.494       |
# |    n_updates            | 2740        |
# |    policy_gradient_loss | 0.000185    |
# |    value_loss           | 5.9         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.71e+03   |
# |    ep_rew_mean          | -8.18      |
# | time/                   |            |
# |    fps                  | 221        |
# |    iterations           | 31         |
# |    time_elapsed         | 286        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01235484 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.17       |
# |    n_updates            | 2750       |
# |    policy_gradient_loss | -0.00474   |
# |    value_loss           | 2.6        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -7.96       |
# | time/                   |             |
# |    fps                  | 221         |
# |    iterations           | 32          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010231437 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.414       |
# |    n_updates            | 2760        |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 2.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+03    |
# |    ep_rew_mean          | -3.99       |
# | time/                   |             |
# |    fps                  | 220         |
# |    iterations           | 33          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.019424714 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.469       |
# |    n_updates            | 2770        |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 3.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+03     |
# |    ep_rew_mean          | -2.76        |
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 34           |
# |    time_elapsed         | 316          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0059038694 |
# |    clip_fraction        | 0.0441       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 2780         |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 11.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+03    |
# |    ep_rew_mean          | 0.916       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 35          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006464907 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0738      |
# |    n_updates            | 2790        |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | 0.899       |
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 36          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016431002 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.52        |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.61e+03   |
# |    ep_rew_mean          | 0.877      |
# | time/                   |            |
# |    fps                  | 218        |
# |    iterations           | 37         |
# |    time_elapsed         | 346        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01571657 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.333      |
# |    n_updates            | 2810       |
# |    policy_gradient_loss | -0.00643   |
# |    value_loss           | 6.74       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 0.862       |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 38          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012867594 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8         |
# |    n_updates            | 2820        |
# |    policy_gradient_loss | -0.000371   |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | 2.8         |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 39          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.030556533 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0618      |
# |    n_updates            | 2830        |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 2.74        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 40          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008465048 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0885      |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 6.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 2.74        |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 41          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.023418441 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.414       |
# |    n_updates            | 2850        |
# |    policy_gradient_loss | 0.00402     |
# |    value_loss           | 3.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.58e+03    |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 42          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011795073 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00267    |
# |    n_updates            | 2860        |
# |    policy_gradient_loss | 0.000521    |
# |    value_loss           | 0.0591      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+03     |
# |    ep_rew_mean          | 0.691        |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 43           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0058273785 |
# |    clip_fraction        | 0.0882       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00475     |
# |    n_updates            | 2870         |
# |    policy_gradient_loss | -0.00299     |
# |    value_loss           | 1.91         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.58e+03    |
# |    ep_rew_mean          | 1.31        |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 44          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010248708 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 2880        |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 0.582       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.58e+03    |
# |    ep_rew_mean          | -0.339      |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 45          |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010117694 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00298     |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 2.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.56e+03    |
# |    ep_rew_mean          | 0.342       |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 46          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009893211 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65        |
# |    n_updates            | 2900        |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 3.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.57e+03    |
# |    ep_rew_mean          | 0.355       |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 47          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010316368 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0589      |
# |    n_updates            | 2910        |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 4.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+03    |
# |    ep_rew_mean          | 3.71        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 48          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011510859 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.421       |
# |    n_updates            | 2920        |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 4.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 3.64        |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 49          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007548816 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.72        |
# |    n_updates            | 2930        |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 3.2         |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 50          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.014952014 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.38        |
# |    n_updates            | 2940        |
# |    policy_gradient_loss | 0.00132     |
# |    value_loss           | 4.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.5e+03      |
# |    ep_rew_mean          | 3.95         |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 51           |
# |    time_elapsed         | 486          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0044575296 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0918       |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 3.02         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 3.89        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 52          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011944795 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.567       |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00754    |
# |    value_loss           | 3.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 4.56        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 53          |
# |    time_elapsed         | 506         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.015763521 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 2970        |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 2.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.48e+03    |
# |    ep_rew_mean          | 5.56        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 54          |
# |    time_elapsed         | 516         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.007916277 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.117       |
# |    n_updates            | 2980        |
# |    policy_gradient_loss | 0.000393    |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+03    |
# |    ep_rew_mean          | 5.51        |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 55          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.009676149 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 6.72        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.5e+03      |
# |    ep_rew_mean          | 5.46         |
# ...
# |    loss                 | 0.261       |
# |    n_updates            | 3730        |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 1.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 130         |
# |    time_elapsed         | 1191        |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.014548041 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 3740        |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 1.9         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.67e+03     |
# |    ep_rew_mean          | 18.6         |
# | time/                   |              |
# |    fps                  | 223          |
# |    iterations           | 131          |
# |    time_elapsed         | 1199         |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0072407136 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.355        |
# |    n_updates            | 3750         |
# |    policy_gradient_loss | -0.00826     |
# |    value_loss           | 2.19         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 223         |
# |    iterations           | 132         |
# |    time_elapsed         | 1207        |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.016743116 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.156       |
# |    n_updates            | 3760        |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 5.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.65e+03    |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 133         |
# |    time_elapsed         | 1215        |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.016470114 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0332      |
# |    n_updates            | 3770        |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 0.218       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.67e+03   |
# |    ep_rew_mean          | 18.4       |
# | time/                   |            |
# |    fps                  | 224        |
# |    iterations           | 134        |
# |    time_elapsed         | 1223       |
# |    total_timesteps      | 274432     |
# | train/                  |            |
# |    approx_kl            | 0.03589528 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.425      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.45       |
# |    n_updates            | 3780       |
# |    policy_gradient_loss | -0.00276   |
# |    value_loss           | 7.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 135         |
# |    time_elapsed         | 1231        |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.016722858 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.01        |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.000793   |
# |    value_loss           | 3.28        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.67e+03  |
# |    ep_rew_mean          | 18.5      |
# | time/                   |           |
# |    fps                  | 224       |
# |    iterations           | 136       |
# |    time_elapsed         | 1239      |
# |    total_timesteps      | 278528    |
# | train/                  |           |
# |    approx_kl            | 0.0157368 |
# |    clip_fraction        | 0.148     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.28     |
# |    explained_variance   | 0.425     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0324    |
# |    n_updates            | 3800      |
# |    policy_gradient_loss | -0.00624  |
# |    value_loss           | 1.84      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.7e+03    |
# |    ep_rew_mean          | 18.1       |
# | time/                   |            |
# |    fps                  | 224        |
# |    iterations           | 137        |
# |    time_elapsed         | 1247       |
# |    total_timesteps      | 280576     |
# | train/                  |            |
# |    approx_kl            | 0.01727068 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.69       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.219      |
# |    n_updates            | 3810       |
# |    policy_gradient_loss | -0.0248    |
# |    value_loss           | 0.488      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 138         |
# |    time_elapsed         | 1255        |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.008815142 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.279       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0167      |
# |    n_updates            | 3820        |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.401       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.7e+03     |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 139         |
# |    time_elapsed         | 1265        |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.007213315 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0849      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 3830        |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 2.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.7e+03     |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 140         |
# |    time_elapsed         | 1274        |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.009556112 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15        |
# |    n_updates            | 3840        |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 8.16        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.7e+03    |
# |    ep_rew_mean          | 17.3       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 141        |
# |    time_elapsed         | 1282       |
# |    total_timesteps      | 288768     |
# | train/                  |            |
# |    approx_kl            | 0.01131785 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.28       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0688     |
# |    n_updates            | 3850       |
# |    policy_gradient_loss | 0.00134    |
# |    value_loss           | 2.17       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 142         |
# |    time_elapsed         | 1290        |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.010687485 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83        |
# |    n_updates            | 3860        |
# |    policy_gradient_loss | -0.00299    |
# |    value_loss           | 6.12        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.68e+03   |
# |    ep_rew_mean          | 19.7       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 143        |
# |    time_elapsed         | 1298       |
# |    total_timesteps      | 292864     |
# | train/                  |            |
# |    approx_kl            | 0.01464808 |
# |    clip_fraction        | 0.0429     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35       |
# |    n_updates            | 3870       |
# |    policy_gradient_loss | -0.00178   |
# |    value_loss           | 9.44       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.68e+03   |
# |    ep_rew_mean          | 20.9       |
# | time/                   |            |
# |    fps                  | 225        |
# |    iterations           | 144        |
# |    time_elapsed         | 1306       |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.01164483 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.94       |
# |    n_updates            | 3880       |
# |    policy_gradient_loss | -0.00632   |
# |    value_loss           | 1.49       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.68e+03    |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 145         |
# |    time_elapsed         | 1314        |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.006463048 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.09        |
# |    n_updates            | 3890        |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.68e+03    |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 146         |
# |    time_elapsed         | 1323        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.009519928 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 0.0191      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.7e+03     |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 147         |
# |    time_elapsed         | 1332        |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.012562737 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00748    |
# |    n_updates            | 3910        |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.276       |
# -----------------------------------------

# %%
model.learn(total_timesteps=600000)
# Out:
# Logging to Training\Logs\PPO_21
# -----------------------------
# | time/              |      |
# |    fps             | 346  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.62e+03    |
# |    ep_rew_mean          | 5.41        |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012137771 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0115      |
# |    n_updates            | 5400        |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00743     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.55e+03   |
# |    ep_rew_mean          | 5.08       |
# | time/                   |            |
# |    fps                  | 264        |
# |    iterations           | 3          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01995743 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.2        |
# |    n_updates            | 5410       |
# |    policy_gradient_loss | -0.00713   |
# |    value_loss           | 1.62       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.5e+03     |
# |    ep_rew_mean          | 4.71        |
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012030059 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.08        |
# |    n_updates            | 5420        |
# |    policy_gradient_loss | -0.00694    |
# |    value_loss           | 1.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18e+03    |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 5           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017712347 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.914       |
# |    n_updates            | 5430        |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25e+03    |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 6           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007410477 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.36        |
# |    n_updates            | 5440        |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.29e+03    |
# |    ep_rew_mean          | -30.1       |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 7           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012722273 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.936       |
# |    n_updates            | 5450        |
# |    policy_gradient_loss | -0.00397    |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.33e+03      |
# |    ep_rew_mean          | -25           |
# | time/                   |               |
# |    fps                  | 246           |
# |    iterations           | 8             |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00078689546 |
# |    clip_fraction        | 0.00352       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | 0.636         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.737         |
# |    n_updates            | 5460          |
# |    policy_gradient_loss | -0.000728     |
# |    value_loss           | 1.75          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33e+03    |
# |    ep_rew_mean          | -25         |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 9           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013722435 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.316       |
# |    n_updates            | 5470        |
# |    policy_gradient_loss | -0.00992    |
# |    value_loss           | 2.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -7.88       |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 10          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013002653 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0253      |
# |    n_updates            | 5480        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -7.88       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 11          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002808988 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.317       |
# |    n_updates            | 5490        |
# |    policy_gradient_loss | 0.000497    |
# |    value_loss           | 9.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | -6.68       |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 12          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008848778 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0022     |
# |    n_updates            | 5500        |
# |    policy_gradient_loss | 0.00256     |
# |    value_loss           | 0.0561      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09e+03    |
# |    ep_rew_mean          | -5.67       |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 13          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011325373 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0069      |
# |    n_updates            | 5510        |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 0.311       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.14e+03   |
# |    ep_rew_mean          | -4.7       |
# | time/                   |            |
# |    fps                  | 246        |
# |    iterations           | 14         |
# |    time_elapsed         | 116        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01282157 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.0661     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.284      |
# |    n_updates            | 5520       |
# |    policy_gradient_loss | 0.00016    |
# |    value_loss           | 2.22       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.17e+03    |
# |    ep_rew_mean          | -3.97       |
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 15          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010826139 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0628      |
# |    n_updates            | 5530        |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 2.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | -0.553      |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 16          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016393906 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0692      |
# |    n_updates            | 5540        |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 2.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.11e+03    |
# |    ep_rew_mean          | -0.131      |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 17          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010791324 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 5550        |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 3.35        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.04e+03     |
# |    ep_rew_mean          | 2.65         |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 18           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0075365943 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0436       |
# |    n_updates            | 5560         |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 1.83         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04e+03   |
# |    ep_rew_mean          | 2.65       |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 19         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01019354 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.0483     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.1        |
# |    n_updates            | 5570       |
# |    policy_gradient_loss | -0.00474   |
# |    value_loss           | 5.77       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 2.45        |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 20          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022368412 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00607    |
# |    n_updates            | 5580        |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 0.0656      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98e+03    |
# |    ep_rew_mean          | 4.4         |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 21          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.020160813 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0334      |
# |    n_updates            | 5590        |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -3.86       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 22          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004039164 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0899      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.258       |
# |    n_updates            | 5600        |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.03e+03    |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 23          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.007369379 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.0857     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0859      |
# |    n_updates            | 5610        |
# |    policy_gradient_loss | -0.000839   |
# |    value_loss           | 1.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97e+03    |
# |    ep_rew_mean          | -8.99       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 24          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011072742 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.179       |
# |    n_updates            | 5620        |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 1.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 25          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009312473 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.3         |
# |    n_updates            | 5630        |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 3.7         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.95e+03   |
# |    ep_rew_mean          | -17.3      |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 26         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01196324 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.079      |
# |    n_updates            | 5640       |
# |    policy_gradient_loss | -0.00355   |
# |    value_loss           | 1.64       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.97e+03   |
# |    ep_rew_mean          | -16.5      |
# | time/                   |            |
# |    fps                  | 245        |
# |    iterations           | 27         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01842549 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.495      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.389      |
# |    n_updates            | 5650       |
# |    policy_gradient_loss | -0.00711   |
# |    value_loss           | 1.39       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97e+03    |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 28          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010256796 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.221       |
# |    n_updates            | 5660        |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 1.08        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | -16.2        |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 29           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0050051785 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0593       |
# |    n_updates            | 5670         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 0.384        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+03    |
# |    ep_rew_mean          | -15.5       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 30          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014127031 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.01        |
# |    n_updates            | 5680        |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+03    |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 31          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007694586 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 5690        |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 1.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 32           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0055441335 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71         |
# |    n_updates            | 5700         |
# |    policy_gradient_loss | -0.000869    |
# |    value_loss           | 2.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+03    |
# |    ep_rew_mean          | -21.2       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 33          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014653576 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00667     |
# |    n_updates            | 5710        |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.174       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -24.5       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 34          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016074987 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 5720        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.793       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91e+03    |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 35          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.021514203 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.518       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.033       |
# |    n_updates            | 5730        |
# |    policy_gradient_loss | -0.00299    |
# |    value_loss           | 0.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+03    |
# |    ep_rew_mean          | -25.8       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 36          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009454006 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.142       |
# |    n_updates            | 5740        |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 2.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89e+03    |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 37          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011287015 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0787      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 5750        |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 2.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91e+03    |
# |    ep_rew_mean          | -23.3       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 38          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016132329 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0702      |
# |    n_updates            | 5760        |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+03    |
# |    ep_rew_mean          | -22.5       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 39          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013092151 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65        |
# |    n_updates            | 5770        |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 2.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+03     |
# |    ep_rew_mean          | -21.9        |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 40           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0093597965 |
# |    clip_fraction        | 0.19         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76         |
# |    n_updates            | 5780         |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 1.69         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+03    |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 41          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.017329102 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0931      |
# |    n_updates            | 5790        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -21.3       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 42          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012316583 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.875      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.013       |
# |    n_updates            | 5800        |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 0.0386      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96e+03    |
# |    ep_rew_mean          | -20.7       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 43          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.015345826 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00139     |
# |    n_updates            | 5810        |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 0.289       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98e+03    |
# |    ep_rew_mean          | -23.9       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 44          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012045767 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.359       |
# |    n_updates            | 5820        |
# |    policy_gradient_loss | -0.00752    |
# |    value_loss           | 1.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 45          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013115529 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0512      |
# |    n_updates            | 5830        |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -21.8       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 46          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017801058 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 5840        |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 5.16        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.96e+03     |
# |    ep_rew_mean          | -21.3        |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 47           |
# |    time_elapsed         | 395          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0121999085 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.929        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0472       |
# |    n_updates            | 5850         |
# |    policy_gradient_loss | -0.00534     |
# |    value_loss           | 0.392        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97e+03    |
# |    ep_rew_mean          | -20.8       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 48          |
# |    time_elapsed         | 403         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016670357 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.542      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00252     |
# |    n_updates            | 5860        |
# |    policy_gradient_loss | 0.00274     |
# |    value_loss           | 0.242       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -20.2       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 49          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019953871 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0763      |
# |    n_updates            | 5870        |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -19.7       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 50          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011397144 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0539      |
# |    n_updates            | 5880        |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 1.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 51          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.016653582 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31        |
# |    n_updates            | 5890        |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 1.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -19.3        |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 52           |
# |    time_elapsed         | 437          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0012075305 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92         |
# |    n_updates            | 5900         |
# |    policy_gradient_loss | -0.000703    |
# |    value_loss           | 4.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -18.9       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 53          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.018734612 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 5910        |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.0265      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 54          |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.012949705 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 5920        |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 0.197       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -19.4        |
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 55           |
# |    time_elapsed         | 463          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0074669383 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34         |
# |    n_updates            | 5930         |
# |    policy_gradient_loss | -0.00441     |
# |    value_loss           | 6.27         |
# ------------------------------------------
# ----------------------------------------
# ...
# |    value_loss           | 0.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+03    |
# |    ep_rew_mean          | -22.2       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 276         |
# |    time_elapsed         | 2342        |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.014170019 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0674      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 8140        |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 4.84        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.96e+03     |
# |    ep_rew_mean          | -24.4        |
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 277          |
# |    time_elapsed         | 2350         |
# |    total_timesteps      | 567296       |
# | train/                  |              |
# |    approx_kl            | 0.0063779997 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45         |
# |    n_updates            | 8150         |
# |    policy_gradient_loss | 0.00338      |
# |    value_loss           | 1.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96e+03    |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 278         |
# |    time_elapsed         | 2359        |
# |    total_timesteps      | 569344      |
# | train/                  |             |
# |    approx_kl            | 0.017734535 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0288      |
# |    n_updates            | 8160        |
# |    policy_gradient_loss | -0.000317   |
# |    value_loss           | 1.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96e+03    |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 279         |
# |    time_elapsed         | 2367        |
# |    total_timesteps      | 571392      |
# | train/                  |             |
# |    approx_kl            | 0.023031812 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0419      |
# |    n_updates            | 8170        |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.127       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -24.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 280         |
# |    time_elapsed         | 2376        |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.019516582 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.585      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0058     |
# |    n_updates            | 8180        |
# |    policy_gradient_loss | -0.000699   |
# |    value_loss           | 0.243       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -24.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 281         |
# |    time_elapsed         | 2384        |
# |    total_timesteps      | 575488      |
# | train/                  |             |
# |    approx_kl            | 0.011129412 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.0983     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.76        |
# |    n_updates            | 8190        |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 8.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.95e+03    |
# |    ep_rew_mean          | -24.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 282         |
# |    time_elapsed         | 2392        |
# |    total_timesteps      | 577536      |
# | train/                  |             |
# |    approx_kl            | 0.008143943 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 1.77e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00954    |
# |    n_updates            | 8200        |
# |    policy_gradient_loss | 0.00138     |
# |    value_loss           | 0.00209     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96e+03    |
# |    ep_rew_mean          | -26.8       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 283         |
# |    time_elapsed         | 2401        |
# |    total_timesteps      | 579584      |
# | train/                  |             |
# |    approx_kl            | 0.017116636 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.0939      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00522    |
# |    n_updates            | 8210        |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 0.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96e+03    |
# |    ep_rew_mean          | -26.8       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 284         |
# |    time_elapsed         | 2409        |
# |    total_timesteps      | 581632      |
# | train/                  |             |
# |    approx_kl            | 0.009048041 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.00747     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.632       |
# |    n_updates            | 8220        |
# |    policy_gradient_loss | -0.00485    |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98e+03    |
# |    ep_rew_mean          | -29         |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 285         |
# |    time_elapsed         | 2418        |
# |    total_timesteps      | 583680      |
# | train/                  |             |
# |    approx_kl            | 0.009403683 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.965       |
# |    n_updates            | 8230        |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 1.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98e+03    |
# |    ep_rew_mean          | -29         |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 286         |
# |    time_elapsed         | 2426        |
# |    total_timesteps      | 585728      |
# | train/                  |             |
# |    approx_kl            | 0.010703133 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 8240        |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 1           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -29.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 287         |
# |    time_elapsed         | 2435        |
# |    total_timesteps      | 587776      |
# | train/                  |             |
# |    approx_kl            | 0.012753892 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0187      |
# |    n_updates            | 8250        |
# |    policy_gradient_loss | -0.000332   |
# |    value_loss           | 0.00624     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -29.6       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 288         |
# |    time_elapsed         | 2443        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.006592514 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.15        |
# |    n_updates            | 8260        |
# |    policy_gradient_loss | -0.000394   |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -31.3       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 289         |
# |    time_elapsed         | 2452        |
# |    total_timesteps      | 591872      |
# | train/                  |             |
# |    approx_kl            | 0.009299449 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00336     |
# |    n_updates            | 8270        |
# |    policy_gradient_loss | -0.000192   |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -31.3       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 290         |
# |    time_elapsed         | 2460        |
# |    total_timesteps      | 593920      |
# | train/                  |             |
# |    approx_kl            | 0.009757761 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9         |
# |    n_updates            | 8280        |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -31.3       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 291         |
# |    time_elapsed         | 2469        |
# |    total_timesteps      | 595968      |
# | train/                  |             |
# |    approx_kl            | 0.010550265 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0986     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0234      |
# |    n_updates            | 8290        |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -32.5       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 292         |
# |    time_elapsed         | 2478        |
# |    total_timesteps      | 598016      |
# | train/                  |             |
# |    approx_kl            | 0.019249849 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 8300        |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 0.0577      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -33.2       |
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 293         |
# |    time_elapsed         | 2486        |
# |    total_timesteps      | 600064      |
# | train/                  |             |
# |    approx_kl            | 0.029313559 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91        |
# |    n_updates            | 8310        |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.268       |
# -----------------------------------------

# %%
env.close()

# %%
baseline_path = os.path.join('Training', 'Models', 'test_baseline')

# %%
model.save(baseline_path)

# %%
model.learn(total_timesteps=10000)

# %%
model.learn(total_timesteps=1000000)

# %%
model = PPO.load(baseline_path)

# %%
env = GameEnv()

env.reset()
model.set_env(env=env)
model.learn(total_timesteps=100000)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_25
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98       |
# |    ep_rew_mean     | 41       |
# | time/              |          |
# |    fps             | 359      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.39e+03    |
# |    ep_rew_mean          | 23.9        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022528637 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.000246   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0313      |
# |    n_updates            | 8410        |
# |    policy_gradient_loss | 0.0029      |
# |    value_loss           | 6.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017585378 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 8420        |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 1.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.41e+03    |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 4           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013587577 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.751       |
# |    n_updates            | 8430        |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 7.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018430945 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 9.54e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00434    |
# |    n_updates            | 8440        |
# |    policy_gradient_loss | 0.00531     |
# |    value_loss           | 0.00401     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 6           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011338364 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31        |
# |    n_updates            | 8450        |
# |    policy_gradient_loss | 0.00846     |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.42e+03    |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 7           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013022165 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 8460        |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 0.00897     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.42e+03    |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 8           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009635169 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0621      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 8470        |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 9.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.36e+03    |
# |    ep_rew_mean          | 30.5        |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 9           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023018502 |
# |    clip_fraction        | 0.469       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.153      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0529     |
# |    n_updates            | 8480        |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.36e+03     |
# |    ep_rew_mean          | 30.5         |
# | time/                   |              |
# |    fps                  | 266          |
# |    iterations           | 10           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0072513716 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.11         |
# |    n_updates            | 8490         |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 7.47         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.46e+03    |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 11          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020084936 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0771      |
# |    n_updates            | 8500        |
# |    policy_gradient_loss | -0.0311     |
# |    value_loss           | 0.228       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.55e+03    |
# |    ep_rew_mean          | 27.5        |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 12          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.035084248 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 8510        |
# |    policy_gradient_loss | 0.00876     |
# |    value_loss           | 0.279       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+03    |
# |    ep_rew_mean          | 26.3        |
# | time/                   |             |
# |    fps                  | 265         |
# |    iterations           | 13          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018893769 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0496      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.222       |
# |    n_updates            | 8520        |
# |    policy_gradient_loss | 0.00105     |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+03    |
# |    ep_rew_mean          | 26.3        |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 14          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006983767 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.412       |
# |    n_updates            | 8530        |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 1.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+03    |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 15          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011287035 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0333      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0209      |
# |    n_updates            | 8540        |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 0.0132      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.69e+03    |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 16          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010359319 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0747      |
# |    n_updates            | 8550        |
# |    policy_gradient_loss | -0.000747   |
# |    value_loss           | 5.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.69e+03    |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 17          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009238475 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0775      |
# |    n_updates            | 8560        |
# |    policy_gradient_loss | 0.00652     |
# |    value_loss           | 2.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.74e+03    |
# |    ep_rew_mean          | 24.2        |
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 18          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.030219253 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.000147    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00369     |
# |    n_updates            | 8570        |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 0.00498     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.78e+03    |
# |    ep_rew_mean          | 23.3        |
# | time/                   |             |
# |    fps                  | 261         |
# |    iterations           | 19          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017467432 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0135     |
# |    n_updates            | 8580        |
# |    policy_gradient_loss | -0.00551    |
# |    value_loss           | 0.185       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.76e+03     |
# |    ep_rew_mean          | 15.3         |
# | time/                   |              |
# |    fps                  | 261          |
# |    iterations           | 20           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0062914183 |
# |    clip_fraction        | 0.0882       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 8590         |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 1.54         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.77e+03    |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 21          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.025946012 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.532       |
# |    n_updates            | 8600        |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 5.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.77e+03    |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 22          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012911966 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56        |
# |    n_updates            | 8610        |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 4.42        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.8e+03      |
# |    ep_rew_mean          | 13.7         |
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 23           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0099725975 |
# |    clip_fraction        | 0.0988       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.614        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0472       |
# |    n_updates            | 8620         |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 0.16         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+03    |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 24          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019257408 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00583    |
# |    n_updates            | 8630        |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 0.168       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.87e+03     |
# |    ep_rew_mean          | 13.2         |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 25           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0068030357 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.18         |
# |    n_updates            | 8640         |
# |    policy_gradient_loss | -0.000739    |
# |    value_loss           | 1.45         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87e+03    |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 26          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011981187 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00849    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.9         |
# |    n_updates            | 8650        |
# |    policy_gradient_loss | 0.00174     |
# |    value_loss           | 1.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.85e+03     |
# |    ep_rew_mean          | 11.7         |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 27           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0066680126 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.118        |
# |    n_updates            | 8660         |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 0.264        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.87e+03    |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 28          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009967623 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.261       |
# |    n_updates            | 8670        |
# |    policy_gradient_loss | 0.000881    |
# |    value_loss           | 5.23        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.89e+03   |
# |    ep_rew_mean          | 11.3       |
# | time/                   |            |
# |    fps                  | 256        |
# |    iterations           | 29         |
# |    time_elapsed         | 231        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01600451 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.0268     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.97       |
# |    n_updates            | 8680       |
# |    policy_gradient_loss | 0.00353    |
# |    value_loss           | 1.6        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.89e+03     |
# |    ep_rew_mean          | 11.3         |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 30           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0074359216 |
# |    clip_fraction        | 0.236        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.816        |
# |    n_updates            | 8690         |
# |    policy_gradient_loss | 0.00273      |
# |    value_loss           | 1.76         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.89e+03    |
# |    ep_rew_mean          | 12.4        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 31          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013530012 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.000399    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 8700        |
# |    policy_gradient_loss | -0.00551    |
# |    value_loss           | 0.000511    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.91e+03     |
# |    ep_rew_mean          | 8            |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 32           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0028937133 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 8710         |
# |    policy_gradient_loss | 0.000432     |
# |    value_loss           | 3.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.91e+03    |
# |    ep_rew_mean          | 8           |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 33          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008866792 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0906      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 8720        |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+03    |
# |    ep_rew_mean          | 3.92        |
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 34          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.026930096 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00885    |
# |    n_updates            | 8730        |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 0.0153      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.96e+03   |
# |    ep_rew_mean          | 4.05       |
# | time/                   |            |
# |    fps                  | 255        |
# |    iterations           | 35         |
# |    time_elapsed         | 280        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01828913 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.392      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0475    |
# |    n_updates            | 8740       |
# |    policy_gradient_loss | -0.025     |
# |    value_loss           | 0.144      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+03     |
# |    ep_rew_mean          | 4.18         |
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 36           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0086972825 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.273        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.397        |
# |    n_updates            | 8750         |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 2.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.98e+03    |
# |    ep_rew_mean          | 4.18        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 37          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014530729 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.83        |
# |    n_updates            | 8760        |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 2.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 4.18        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 38          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009830255 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.07       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000394   |
# |    n_updates            | 8770        |
# |    policy_gradient_loss | -0.00796    |
# |    value_loss           | 0.000905    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | 1.28        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 39          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015820421 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00812    |
# |    n_updates            | 8780        |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 0.219       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.9e+03      |
# |    ep_rew_mean          | 4.44         |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 40           |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0077606947 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0984       |
# |    n_updates            | 8790         |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 7.46         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.9e+03     |
# |    ep_rew_mean          | 4.44        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 41          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.001431904 |
# |    clip_fraction        | 0.0134      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 8800        |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.87e+03     |
# |    ep_rew_mean          | 5.22         |
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 42           |
# |    time_elapsed         | 334          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0126933195 |
# |    clip_fraction        | 0.135        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0173       |
# |    n_updates            | 8810         |
# |    policy_gradient_loss | -0.00678     |
# |    value_loss           | 0.124        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86e+03    |
# |    ep_rew_mean          | 6.17        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 43          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007364415 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0458      |
# |    n_updates            | 8820        |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 2.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86e+03    |
# |    ep_rew_mean          | 6.17        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 44          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012638263 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0754      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.305       |
# |    n_updates            | 8830        |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 6.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88e+03    |
# |    ep_rew_mean          | 6.14        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 45          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009249378 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0271      |
# |    n_updates            | 8840        |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.0543      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.85e+03    |
# |    ep_rew_mean          | 7.95        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 46          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014232607 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00633     |
# |    n_updates            | 8850        |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 0.298       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+03    |
# |    ep_rew_mean          | 8.63        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 47          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.003968311 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.774       |
# |    n_updates            | 8860        |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 8.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.84e+03    |
# |    ep_rew_mean          | 8.63        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 48          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005497316 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.295       |
# |    n_updates            | 8870        |
# |    policy_gradient_loss | -0.000278   |
# |    value_loss           | 8.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.8e+03     |
# |    ep_rew_mean          | 9.89        |
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 49          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017405773 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.211      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00312     |
# |    n_updates            | 8880        |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 0.0581      |
# -----------------------------------------

# %%
env = GameEnv()
mean_r, mean_d = evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# c:\Users\jahin\anaconda3\envs\myenv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
print(mean_r)
print(mean_d)
# Out:
# 42.912998653016984
# 1.337789709207067

# %%
env.close()

# %%
def piecewise(x):
  y = np.zeros_like(x)
  y[x <= 10] = 0.009
  y[x > 10] = 0.0092 * np.exp(-0.0957 * (x - 10)) - 0.0002
  return y

# %%
# %tensorboard
