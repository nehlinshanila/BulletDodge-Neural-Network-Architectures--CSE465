# %%
import numpy as np

# %%
class Agent:
    def __init__(self, agent_name, agent_index):
        self.index = agent_index
        self.agent = agent_name
        self.health = None
        self.isHit = False
        self.move = True
        self.movement_speed = 1.00
        self.previous_position = np.array([0, 0], dtype=np.float32)
        self.current_position = None
        self.same_position = False
        self.current_step = 0
        self.action = None
        pass

    def agent_action(self, action):

        pass

    def agent_reset(self, width, height):
        padding = 30
        self.current_position = np.array(
            [np.random.uniform(30, width - padding), np.random.uniform(30, width - padding)], dtype=np.float32)

    def step_update(self, action, range_x, range_y):

        if action == 0:
            self.current_position[0] -= self.movement_speed
        elif action == 1:
            self.current_position[0] += self.movement_speed
        elif action == 2:
            self.current_position[1] -= self.movement_speed
        elif action == 3:
            self.current_position[1] += self.movement_speed
        
        self.current_position[0] = np.clip(self.current_position[0], 0, range_x)
        self.current_position[1] = np.clip(self.current_position[1], 0, range_y)

# %%
from gymnasium.spaces import Discrete, Box, MultiDiscrete
from gymnasium import Env
import numpy as np
import pygame
import time

# %%
class GameEnv(Env):
    def __init__(self, screen_width=400, screen_height=400, render_mode='human'):
        super(GameEnv, self).__init__()

        # defining the screen dimension for render purpose
        self.screen_width = screen_width
        self.screen_height = screen_height
        self.render_mode = render_mode

        # defining the observation and action spaces for all the agents
        
        self.observation_space = Box(low=np.array([0, 0, 0, 0], dtype=np.float32),
                                    high=np.array([self.screen_width, self.screen_height, self.screen_width, self.screen_height], dtype=np.float32),
                                    dtype=np.float32)

        # the pygame window should be initialized in the render function

        # setting the total number of agent
        
        self.number_of_prey = 1
        self.number_of_predator = 1
        self.prey_agent = None
        self.predator_agent = None
        self.predator_i_position = None
        self.initial_distance = None
        self.current_distance = None
        self.previous_distance = None
        self.predator_total_reward = 0
        self.number_of_agents = self.number_of_prey + self.number_of_prey

        self.obs = None

        # defining the action space based on total number of predator and prey
        self.action_space = Discrete(4)


        # setting the total number of obstacles
        self.total_obstacles = None

        # keeping a counter to save the total steps
        self.total_steps = 0

        # initializing the pygame
        pygame.init()

        # setting the screen size
        self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
        pygame.display.set_caption('Multi Agent Environment(simple)')
        
        # keep the track of time of the rendering
        self.clock = pygame.time.Clock()

        # *it is set in milisec format (time is sec is time/1000)
        self.total_running_time = 10

        # start the tick timer
        self.start_time = 0
        # print(f'start  time: {self.start_time}')

        # initializing the font
        pygame.font.init()
        self.font = pygame.font.Font(None, 18)

    # this function rerturns the value of the action into 2 digits 
    # if the action_space.sample() gives 1 digit number
    # * if  the number is 3 it will return 03 
    # * if  the number is 14 then it will return 14
    def expand_action_digit(self, action):

        # this basically checks the number if it has 1 then fills the rest with 0
        # if the number is 2 digits then it stays the same
        action = str(action).zfill(2)
        prey_action = int(action[0]) % 4
        predator_action = int(action[1]) % 4
        return prey_action, predator_action
        

    # this method will initialize the number of agents
    # ! this must be called from outside
    def agent_init(self):

        prey_agents = Agent('prey', 0)

        predator_agents = Agent('predator', 0)

        self.prey_agent = prey_agents
        self.predator_agent = predator_agents
        

    # this function is used to explicitly set the number of agents
    # ! this needs to be called from outside
    def set_agent_number(self, prey_number, predator_number):
        self.number_of_predator = predator_number
        self.number_of_prey = prey_number

    # the usual reset function
    def reset(self, seed=0):
        self.start_time = time.time()
        
        self.agent_init()

        self.total_steps = 0
        self.predator_total_reward = 0

        prey = self.prey_agent
        predator = self.predator_agent

        # for prey in self.prey_agents:
        prey.agent_reset(width=self.screen_width, height=self.screen_height)
        # observation.append([prey.index, prey.agent, prey.current_position])

        # for predator in self.predator_agents:
        predator.agent_reset(width=self.screen_width, height=self.screen_height)
        # observation.append([predator.index, predator.agent, predator.current_position])
        
        # setting the predator and prey to their initial position
        self.prey_agent = prey
        self.predator_agent = predator

        # setting the initial position of predator for reward
        self.predator_i_position = self.predator_agent.current_position
        
        # calculating the initial distance of 2 agents
        direction = self.predator_agent.current_position - self.prey_agent.current_position
        self.initial_distance = np.linalg.norm(direction)

        # observation :
        # all the variable values inside the obsercation space needs to be sent inside the observation variable
        observation = np.concatenate([self.prey_agent.current_position, self.predator_agent.current_position])
        self.obs = observation
        # model.set_env(GameEnv())
        # observation = self.initial_distance
        return observation, seed

    # the step function
    # this function is called for every timesteps
    # this function updates the actions or states of agents in the env
    # this function is called default by the algorithms of all sorts
    # * it returns observation, reward, done, truncated, info
    # * any game policy change can be done here
    # * reward must be set here
    def step(self, action):
        
        # initializing the return variables
        done = False
        reward = 0
        truncated = False
        info = {}
        current_time = time.time()
        # print(f'current time: {current_time}')
        # when ever the step is starting set the start time
        # if self.total_steps == 0:
        #     self.start_time = pygame.time.get_ticks()
        # else:
        #     current_time = pygame.time.get_ticks()

        elapsed_time = current_time - self.start_time
        # print(f'elapsed time: {elapsed_time}')
        # handles the pygame window event when closing
        # !if the window still crashes pygame.event needs to be managed properly
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                done = True
                pygame.quit()
        
        # print(f'action: {action}')
        # *the actions are split as required
        # prey_action, predator_action = self.expand_action_digit(action)
        prey_action = action
        prey = self.prey_agent
        prey.step_update(action=prey_action, range_x=self.screen_width - 10, range_y=self.screen_height - 10)
        # print(f'prey: {prey_action}, predator: {predator_action}')

        predator = self.predator_agent         
        predator_action = model.predict(self.obs)
        # print(f'predator_{predator.index} = action:{action} current_position: {predator.current_position}')
        predator.step_update(action=predator_action[0], range_x=self.screen_width - 10, range_y=self.screen_height - 10)
        # print(f'predator_{predator.index}: new_position: {predator.current_position}')
            
        # !observation.append({'index': predator.index, 'name': predator.agent, 'position': predator.current_position})
        # observation = self.predator_agent.current_position
        observation = np.concatenate([self.prey_agent.current_position, self.predator_agent.current_position])

        # print(f'observation: {self.predator_agent.current_position}')
        self.total_steps += 1

        direction = self.predator_agent.current_position - self.prey_agent.current_position

        # Calculate the distance between the centers of the two dots
        distance_between_centers = np.linalg.norm(direction)
        # observation =  distance_between_centers

        self.current_distance = distance_between_centers

        if self.current_distance > self.initial_distance:
            self.initial_distance = self.current_distance
            reward += 0.01
        else:
            reward -= 0.01

        # check everystep if the distance of two agents are:
        # greater than  initial distance?  
        # yes: -reward
        # no: +reward

        # if distance_between_centers > self.initial_distance:
        #     reward -= 0.06
        # else:
        #     reward += 0.01
            
        # Check if there is a collision (distance <= sum of radii)
        if elapsed_time <= self.total_running_time:
            if distance_between_centers <= 20:
                reward -= 50
                done = True
                    # pygame.quit()
                    # self.close()
            # if self.total_steps == 30000:
            #     done = True
        else:
            done = True
            reward += 100
                # pygame.quit()
                # self.close()

        # print(self.total_steps)
        self.render()
        # it will update the total reward everystep
        self.predator_total_reward = reward
        self.obs = observation

        return observation, reward, done, truncated, info
        

    def render(self):
        if self.render_mode == 'human':
            screen = self.screen

            # clear screen
            screen.fill((255, 255, 255))
            prey = self.prey_agent
            pos_x, pos_y = prey.current_position
            prey_radius = 10
            pygame.draw.circle(screen, (0, 0, 255), (int(pos_x), int(pos_y)), prey_radius)

            predator = self.predator_agent
            pos_x, pos_y = predator.current_position
            predator_radius = 10

            pygame.draw.circle(screen, (255, 0, 0), (int(pos_x), int(pos_y)), predator_radius)

            text_surface = self.font.render(f"Reward: {self.predator_total_reward: .5f} initial distance: {self.initial_distance: .2f} current_distance:{self.current_distance: .2f}", True, (0, 0, 0))

            text_rect = text_surface.get_rect()

            text_rect.center = (self.screen_width - 200, 10)

            self.screen.blit(text_surface, text_rect)

            pygame.display.update()

    def close(self):
        pygame.quit()

# %%
model = PPO.load(baseline_path)

# %%
env = GameEnv()
model.set_env(env)
for i in range(0, 5):
    done = False

    # env.agent_init()
    obs, _ = env.reset()
    total_reward = 0
    while not done:
        # predator_action = model.predict(obs)
        # print(predator_action[0])
        action = env.action_space.sample()
        # action = [prey_action, predator_action[0]]
        obs, reward, done, _, _ = env.step(action)
        # total_reward += reward
    print(f'total reward: {reward}')
    print(f'Number of steps: {env.total_steps}')
        # env.render()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# total reward: -50.01
# Number of steps: 226
# total reward: -50.01
# Number of steps: 286
# total reward: -50.01
# Number of steps: 252
# total reward: -50.01
# Number of steps: 166
# total reward: -50.01
# Number of steps: 302

# %%
from stable_baselines3 import PPO, DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
log_path = os.path.join('Training', 'Logs', 'Proximal_reward')
baseline_path = os.path.join('Training', 'Models', 'proxi_baseline')

# %%
env.close()

# %%
prey_log_path = os.path.join('Training', 'Logs', 'Prey_Proximal_reward')
prey_baseline_path = os.path.join('Training', 'Models', 'proxi_baseline_prey')

# %%
env = GameEnv()

# env.reset()
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=prey_log_path)
model.learn(total_timesteps=1000000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\Prey_Proximal_reward\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 228  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 80.2        |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015387304 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.015       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 0.00295     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 80.2         |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 3            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066073216 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0179       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0237      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 4.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | 80           |
# | time/                   |              |
# |    fps                  | 184          |
# |    iterations           | 4            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0112666935 |
# |    clip_fraction        | 0.0693       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0123       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0119      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00778     |
# |    value_loss           | 4.75         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 80.3        |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 5           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011219729 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0289      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00209    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 4.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | 80.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 6           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009422032 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0291      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00845    |
# |    value_loss           | 4.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.08e+03    |
# |    ep_rew_mean          | 80          |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 7           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011402579 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.107      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.418       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00089    |
# |    value_loss           | 35.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.09e+03    |
# |    ep_rew_mean          | 79.8        |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 8           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008501375 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0496     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.805       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 35.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.07e+03     |
# |    ep_rew_mean          | 80           |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 9            |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0028608101 |
# |    clip_fraction        | 0.00483      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.02         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0655       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000626     |
# |    value_loss           | 32           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 80.2        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 10          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010610111 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.0622     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 80.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 11          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014621492 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0224      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 4.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 80.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 12          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018470857 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0174     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 4.4         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.85e+03   |
# |    ep_rew_mean          | 60.5       |
# | time/                   |            |
# |    fps                  | 191        |
# |    iterations           | 13         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.04480262 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.377      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.033     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 4.33       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.86e+03    |
# |    ep_rew_mean          | 61.9        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 14          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006979959 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0425      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 28.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.81e+03     |
# |    ep_rew_mean          | 54.2         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 15           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0039990647 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.354        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 35.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82e+03    |
# |    ep_rew_mean          | 55.8        |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 16          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008296497 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.024       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.78e+03    |
# |    ep_rew_mean          | 51.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 17          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010220097 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.0951     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 35.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.74e+03     |
# |    ep_rew_mean          | 45.5         |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 18           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0041939737 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0572       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000449    |
# |    value_loss           | 42.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+03    |
# |    ep_rew_mean          | 38.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 19          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006829337 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.911       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00468    |
# |    value_loss           | 7.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+03    |
# |    ep_rew_mean          | 33.8        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 20          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006948184 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.503       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.66e+03     |
# |    ep_rew_mean          | 29.8         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 21           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0027534994 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.204        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 6.96         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.66e+03     |
# |    ep_rew_mean          | 31.9         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 22           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0023816708 |
# |    clip_fraction        | 0.00723      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 6.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.67e+03     |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 23           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0010233955 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.0603       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.1         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 41.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.68e+03    |
# |    ep_rew_mean          | 35.4        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 24          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008903657 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.0977     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 27.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.69e+03   |
# |    ep_rew_mean          | 36.9       |
# | time/                   |            |
# |    fps                  | 191        |
# |    iterations           | 25         |
# |    time_elapsed         | 267        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01595432 |
# |    clip_fraction        | 0.0909     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.314      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 65.3       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00546   |
# |    value_loss           | 4.62       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+03    |
# |    ep_rew_mean          | 38.3        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 26          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014813047 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0274      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 3.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | 39.7        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 27          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012443641 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0085     |
# |    value_loss           | 4.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.73e+03    |
# |    ep_rew_mean          | 40.9        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 28          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.020350745 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00381    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 3.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.71e+03    |
# |    ep_rew_mean          | 39.2        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 29          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010353961 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 4.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.69e+03    |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 30          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009295523 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0658      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.68e+03      |
# |    ep_rew_mean          | 35            |
# | time/                   |               |
# |    fps                  | 191           |
# |    iterations           | 31            |
# |    time_elapsed         | 331           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00072612247 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.23         |
# |    explained_variance   | 0.416         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.43          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000712     |
# |    value_loss           | 38            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.67e+03     |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 32           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0018648729 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 8.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.64e+03     |
# |    ep_rew_mean          | 32.8         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 33           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0001804684 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.459        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.7         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00018     |
# |    value_loss           | 38           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.64e+03     |
# |    ep_rew_mean          | 33.9         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 34           |
# |    time_elapsed         | 364          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0037748227 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.0274      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 49.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+03    |
# |    ep_rew_mean          | 31.8        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 35          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014014067 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.8        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 31          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 30.9         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 36           |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0054068076 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.531        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00398     |
# |    value_loss           | 5.17         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+03   |
# |    ep_rew_mean          | 32         |
# | time/                   |            |
# |    fps                  | 191        |
# |    iterations           | 37         |
# |    time_elapsed         | 396        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00690616 |
# |    clip_fraction        | 0.0298     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.757      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.21       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00647   |
# |    value_loss           | 9.78       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | 31.2        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 38          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011794167 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0413      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.88        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 44.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 32.2         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 39           |
# |    time_elapsed         | 417          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0010290327 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.84         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00092     |
# |    value_loss           | 52.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.58e+03     |
# |    ep_rew_mean          | 28.6         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 40           |
# |    time_elapsed         | 428          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0043457714 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.0251       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.414        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000951    |
# |    value_loss           | 39.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.56e+03    |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 41          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007523036 |
# |    clip_fraction        | 0.0241      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.56e+03   |
# |    ep_rew_mean          | 29.2       |
# | time/                   |            |
# |    fps                  | 191        |
# |    iterations           | 42         |
# |    time_elapsed         | 450        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01183375 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.0626    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.9       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00889   |
# |    value_loss           | 40.5       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.57e+03     |
# |    ep_rew_mean          | 30.1         |
# | time/                   |              |
# |    fps                  | 191          |
# |    iterations           | 43           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0081978515 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0954       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.4         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 40.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.58e+03    |
# |    ep_rew_mean          | 31          |
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 44          |
# |    time_elapsed         | 470         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006736667 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0948      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.61        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 31.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+03    |
# |    ep_rew_mean          | 31.9        |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 45          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008061071 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.241       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 34.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | 32.7        |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 46          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009735697 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.5        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 29.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 33.5        |
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 47          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010052435 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.1        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 37.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | 32.7        |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 48          |
# |    time_elapsed         | 508         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009581371 |
# |    clip_fraction        | 0.0684      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.9        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 33.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 31.1         |
# | time/                   |              |
# |    fps                  | 193          |
# |    iterations           | 49           |
# |    time_elapsed         | 517          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0028099124 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000193    |
# |    value_loss           | 46.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 29.5        |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 50          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007034734 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 7.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.59e+03    |
# |    ep_rew_mean          | 26.8        |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 51          |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010122031 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 4.11        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.59e+03     |
# |    ep_rew_mean          | 25.4         |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 52           |
# |    time_elapsed         | 546          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0068474514 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.987        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 9.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.6e+03     |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 53          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.011195667 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.61        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 4.55        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.6e+03      |
# |    ep_rew_mean          | 27           |
# | time/                   |              |
# |    fps                  | 195          |
# |    iterations           | 54           |
# |    time_elapsed         | 565          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0047722077 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0062      |
# |    value_loss           | 42.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 27.8        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 55          |
# |    time_elapsed         | 576         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010133947 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# ...
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | 62          |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 465         |
# |    time_elapsed         | 5550        |
# |    total_timesteps      | 952320      |
# | train/                  |             |
# |    approx_kl            | 0.011987949 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | -0.00833    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33          |
# |    n_updates            | 4640        |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 39.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.26e+03     |
# |    ep_rew_mean          | 62           |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 466          |
# |    time_elapsed         | 5563         |
# |    total_timesteps      | 954368       |
# | train/                  |              |
# |    approx_kl            | 0.0020447508 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.2         |
# |    n_updates            | 4650         |
# |    policy_gradient_loss | 0.00205      |
# |    value_loss           | 60.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | 62          |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 467         |
# |    time_elapsed         | 5577        |
# |    total_timesteps      | 956416      |
# | train/                  |             |
# |    approx_kl            | 0.021642935 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 4660        |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 48.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.26e+03     |
# |    ep_rew_mean          | 60.5         |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 468          |
# |    time_elapsed         | 5590         |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0037614303 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.803       |
# |    explained_variance   | 0.414        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05         |
# |    n_updates            | 4670         |
# |    policy_gradient_loss | -0.00087     |
# |    value_loss           | 26.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | 59.1        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 469         |
# |    time_elapsed         | 5603        |
# |    total_timesteps      | 960512      |
# | train/                  |             |
# |    approx_kl            | 0.010351878 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 4680        |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 44          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | 57.6        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 470         |
# |    time_elapsed         | 5617        |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.011213154 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.766      |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.587       |
# |    n_updates            | 4690        |
# |    policy_gradient_loss | 0.00148     |
# |    value_loss           | 36.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.26e+03     |
# |    ep_rew_mean          | 59           |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 471          |
# |    time_elapsed         | 5630         |
# |    total_timesteps      | 964608       |
# | train/                  |              |
# |    approx_kl            | 0.0016316983 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96         |
# |    n_updates            | 4700         |
# |    policy_gradient_loss | 0.00119      |
# |    value_loss           | 13.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | 60.3        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 472         |
# |    time_elapsed         | 5644        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.012625982 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.53        |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -5.39e-05   |
# |    value_loss           | 37.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+03     |
# |    ep_rew_mean          | 57.4         |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 473          |
# |    time_elapsed         | 5657         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0025049332 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.546       |
# |    explained_variance   | 0.126        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73         |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | 0.000328     |
# |    value_loss           | 32.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+03     |
# |    ep_rew_mean          | 57.4         |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 474          |
# |    time_elapsed         | 5671         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0028503928 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.38         |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 27.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+03     |
# |    ep_rew_mean          | 55.9         |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 475          |
# |    time_elapsed         | 5684         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0054953494 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.7         |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | 0.00122      |
# |    value_loss           | 40.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.26e+03     |
# |    ep_rew_mean          | 54.5         |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 476          |
# |    time_elapsed         | 5698         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0056225667 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.638       |
# |    explained_variance   | -0.149       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.2         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00389     |
# |    value_loss           | 50.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+03    |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 477         |
# |    time_elapsed         | 5711        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.010431551 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | -0.157      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00359    |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | 0.000692    |
# |    value_loss           | 6.7         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+03     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 478          |
# |    time_elapsed         | 5725         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0032953806 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.459       |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.7         |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -5.59e-05    |
# |    value_loss           | 42           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.28e+03     |
# |    ep_rew_mean          | 54.4         |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 479          |
# |    time_elapsed         | 5738         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0020440244 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | 0.000984     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.000503    |
# |    value_loss           | 44.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | 54.3        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 480         |
# |    time_elapsed         | 5751        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.010150533 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.0814      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.176       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 42.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.28e+03   |
# |    ep_rew_mean          | 54.3       |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 481        |
# |    time_elapsed         | 5765       |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.00290627 |
# |    clip_fraction        | 0.0125     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.214     |
# |    explained_variance   | 0.128      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.552      |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.000158  |
# |    value_loss           | 51.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.28e+03     |
# |    ep_rew_mean          | 54.3         |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 482          |
# |    time_elapsed         | 5778         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0025853016 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41           |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | 0.000237     |
# |    value_loss           | 32           |
# ------------------------------------------

# %%
# %tensorboard
